# %% [markdown]
# # Getting started with CoAuthor
#
# **Goal: Download and read the CoAuthor dataset**
#
# Steps
# 1. Download CoAuthor
# 2. Read writing sessions
# 3. Examine events
#
# Below sections of this .ipynb come from code from CoAuthor [LINKED HERE](https://colab.research.google.com/drive/1nUGXP9l_jelbB4X65J0ivUvLgQz1RK1C?usp=sharing)
#
# * Download CoAuthor
# * Read writing sessions
# * Examine events

# %% [markdown]
# ## 1. Download CoAuthor

# %% [markdown]
# ##

# %%
# !wget https://cs.stanford.edu/~minalee/zip/chi2022-coauthor-v1.0.zip
# !unzip -q chi2022-coauthor-v1.0.zip
# !rm chi2022-coauthor-v1.0.zip
# Out:
# --2025-03-02 22:21:42--  https://cs.stanford.edu/~minalee/zip/chi2022-coauthor-v1.0.zip
# Resolving cs.stanford.edu (cs.stanford.edu)... 171.64.64.64
# Connecting to cs.stanford.edu (cs.stanford.edu)|171.64.64.64|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 49956179 (48M) [application/zip]
# Saving to: ‘chi2022-coauthor-v1.0.zip.1’
#
# chi2022-coauthor-v1 100%[===================>]  47.64M  3.35MB/s    in 12s
#
# 2025-03-02 22:21:54 (4.10 MB/s) - ‘chi2022-coauthor-v1.0.zip.1’ saved [49956179/49956179]
#
# replace coauthor-v1.0/e0435f4cf6fc435c872ffc5b66b66b0c.jsonl? [y]es, [n]o, [A]ll, [N]one, [r]ename: ^C

# %%
import os

dataset_dir = './coauthor-v1.0'
paths = [
    os.path.join(dataset_dir, path)
    for path in os.listdir(dataset_dir)
    if path.endswith('jsonl')
]

print(f'Successfully downloaded {len(paths)} writing sessions in CoAuthor!')
# Out:
# Successfully downloaded 1447 writing sessions in CoAuthor!

# %%
# !pip install transformers
# !pip install sacremoses
# !pip install numpy
# !pip install nltk
# !pip install unidecode
# Out:
# Requirement already satisfied: transformers in /opt/anaconda3/lib/python3.12/site-packages (4.48.1)
# Requirement already satisfied: filelock in /opt/anaconda3/lib/python3.12/site-packages (from transformers) (3.13.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.24.0 in /opt/anaconda3/lib/python3.12/site-packages (from transformers) (0.27.1)
# Requirement already satisfied: numpy>=1.17 in /opt/anaconda3/lib/python3.12/site-packages (from transformers) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /opt/anaconda3/lib/python3.12/site-packages (from transformers) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in /opt/anaconda3/lib/python3.12/site-packages (from transformers) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /opt/anaconda3/lib/python3.12/site-packages (from transformers) (2024.9.11)
# Requirement already satisfied: requests in /opt/anaconda3/lib/python3.12/site-packages (from transformers) (2.32.3)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /opt/anaconda3/lib/python3.12/site-packages (from transformers) (0.21.0)
# Requirement already satisfied: safetensors>=0.4.1 in /opt/anaconda3/lib/python3.12/site-packages (from transformers) (0.5.2)
# Requirement already satisfied: tqdm>=4.27 in /opt/anaconda3/lib/python3.12/site-packages (from transformers) (4.66.5)
# Requirement already satisfied: fsspec>=2023.5.0 in /opt/anaconda3/lib/python3.12/site-packages (from huggingface-hub<1.0,>=0.24.0->transformers) (2024.6.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /opt/anaconda3/lib/python3.12/site-packages (from huggingface-hub<1.0,>=0.24.0->transformers) (4.11.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/anaconda3/lib/python3.12/site-packages (from requests->transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/lib/python3.12/site-packages (from requests->transformers) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/anaconda3/lib/python3.12/site-packages (from requests->transformers) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/lib/python3.12/site-packages (from requests->transformers) (2024.12.14)
# Requirement already satisfied: sacremoses in /opt/anaconda3/lib/python3.12/site-packages (0.1.1)
# Requirement already satisfied: regex in /opt/anaconda3/lib/python3.12/site-packages (from sacremoses) (2024.9.11)
# Requirement already satisfied: click in /opt/anaconda3/lib/python3.12/site-packages (from sacremoses) (8.1.7)
# Requirement already satisfied: joblib in /opt/anaconda3/lib/python3.12/site-packages (from sacremoses) (1.4.2)
# Requirement already satisfied: tqdm in /opt/anaconda3/lib/python3.12/site-packages (from sacremoses) (4.66.5)
# Requirement already satisfied: numpy in /opt/anaconda3/lib/python3.12/site-packages (1.26.4)
# Requirement already satisfied: nltk in /opt/anaconda3/lib/python3.12/site-packages (3.9.1)
# Requirement already satisfied: click in /opt/anaconda3/lib/python3.12/site-packages (from nltk) (8.1.7)
# Requirement already satisfied: joblib in /opt/anaconda3/lib/python3.12/site-packages (from nltk) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /opt/anaconda3/lib/python3.12/site-packages (from nltk) (2024.9.11)
# Requirement already satisfied: tqdm in /opt/anaconda3/lib/python3.12/site-packages (from nltk) (4.66.5)
# Requirement already satisfied: unidecode in /opt/anaconda3/lib/python3.12/site-packages (1.3.8)

# %% [markdown]
# ## 2. Read writing sessions and workerID info

# %%
import json
import pandas as pd

def read_writing_session(path):
    events = []
    with open(path, 'r') as f:
        for event in f:
            events.append(json.loads(event))
    print(f'Successfully read {len(events)} events in a writing session from {path}')
    return events

# %%
workerID = pd.read_csv('WorkerID and SessionID.csv')
workerID
# Out:
#            worker_id                        session_id
# 0     A2QX3YJXAAHHVV  36bc101319da4b3590b96bce76f7c02c
# 1     A394JO4NEPCY3M  9aca14b9d4bc4e4b9b240782bd72c6db
# 2     A2QKAA5YS0P4CI  499f9577962c4a2c98aee3f5b6098a71
# 3      AZLZA0Q87TJZO  7267ada18a784f5089b55427212251b3
# 4     A2YTQDLACTLIBA  1a14bae2ca9f422ea8779752233a203a
# ...              ...                               ...
# 1440   A2W121DQXNQK1  4c9727b380f34b5baa3d4407f8d91656
# 1441  A1PTH9KTRO06EG  c25b2c082a184e678a841035032b5468
# 1442  A1TW2BZRRS874Z  761aaf53b31f4cfda836ca0802f22278
# 1443   A2W121DQXNQK1  c2395534dfb74c8ab70eec8f139ed2bc
# 1444  A1TW2BZRRS874Z  85a0e0a84eb147eeb0f2db0b946bab2e
#
# [1445 rows x 2 columns]

# %% [markdown]
# ## 3. Getting User text and AI suggestions

# %%
from collections import defaultdict

def reconstruct_user_text(events):
    ''' Creates text from events by combining text-insert and text-delete events.'''
    user_texts = []
    current_text = ""

    # Sort events by eventNum
    sorted_events = sorted(events, key=lambda e: e["eventNum"])

    for event in sorted_events:
        event_type = event["eventName"]
        text_delta = event["textDelta"]

        if event_type == "text-insert" and text_delta:
            extracted_text = ""
            for op in text_delta['ops']:
                if 'insert' in op:
                    extracted_text += op['insert']
            current_text += extracted_text

        elif event_type == "text-delete" and text_delta:
            delete_len = 0
            for op in text_delta['ops']:
                if 'delete' in op:
                    delete_len += op['delete']
                elif 'retain' in op:
                    pass
            current_text = current_text[:-delete_len]


        # Store finalized text if user completes a thought
        if event_type == "suggestion-get" or event_type == "suggestion-select":
            if current_text.strip():
                user_texts.append(current_text.strip())
                current_text = ""

    return user_texts

# %%
def extract_selected_ai_suggestions(events):
    ai_suggestions = []  # Stores accepted AI-generated suggestions
    last_suggestion_open = None  # Store the most recent `suggestion-open` event

    for event in events:
        if event["eventName"] == "suggestion-open" and event.get("currentSuggestions"):
            last_suggestion_open = event  # Save latest `suggestion-open` event

        elif event["eventName"] == "suggestion-select":
            if last_suggestion_open and last_suggestion_open.get("currentSuggestions"):
                selected_index = event.get("currentSuggestionIndex", -1)

                # Ensure selected index is valid
                if 0 <= selected_index < len(last_suggestion_open["currentSuggestions"]):
                    selected_suggestion = last_suggestion_open["currentSuggestions"][selected_index]["trimmed"]
                    ai_suggestions.append(selected_suggestion)

    return ai_suggestions

# %% [markdown]
# ## 4. Creating helper functions

# %% [markdown]
# Helper functions include getting the information on whether the accepted or rejected the text.

# %%
def extract_acceptance_status(events):
    """Track if a suggestion was accepted or rejected."""
    acceptance_status = []  # Stores 'accepted' or 'rejected'
    last_suggestion_open = None  # Store the most recent `suggestion-open`

    for event in events:
        if event["eventName"] == "suggestion-open" and event.get("currentSuggestions"):
            last_suggestion_open = event  # Save the latest `suggestion-open`

        elif event["eventName"] == "suggestion-select" and last_suggestion_open:
            # Suggestion selected
            acceptance_status.append('accepted')
            last_suggestion_open = None  # Reset, since we handled the acceptance

        elif event["eventName"] == "suggestion-close" and last_suggestion_open:
            # Suggestion closed without selection (rejected)
            acceptance_status.append('rejected')
            last_suggestion_open = None  # Reset, since we handled the rejection

    return acceptance_status

# %% [markdown]
# ## 5. Tone Detection Functions

# %% [markdown]
# Here we use RoBERTa GoEmotions for our emotion classifier. Downloading the model here.

# %%
from transformers import pipeline

# Load emotion classification model
emotion_classifier = pipeline("text-classification", model="j-hartmann/emotion-english-distilroberta-base", return_all_scores=True)
# Out:
# Device set to use mps:0
# /opt/anaconda3/lib/python3.12/site-packages/transformers/pipelines/text_classification.py:106: UserWarning: `return_all_scores` is now deprecated,  if want a similar functionality use `top_k=None` instead of `return_all_scores=True` or `top_k=1` instead of `return_all_scores=False`.
#   warnings.warn(

# %%
def get_emotion_vector(text):
  '''Returns a vector of emotion scores for a given text.'''
  result = emotion_classifier(text)[0]
  scores = {emotion['label']: emotion['score'] for emotion in result}
  return scores, np.array(list(scores.values()))

# %%
from scipy.spatial.distance import jensenshannon
import numpy as np

def similarity_jsd(vector1, vector2):
    ''' Calculate JSD similarity between two vectors.'''
    jsd =  jensenshannon(vector1, vector2)
    similarity = 1 - jsd
    return similarity

# %%
# !python -m spacy download en_core_web_sm
# Out:
# Collecting en-core-web-sm==3.8.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.8.0/en_core_web_sm-3.8.0-py3-none-any.whl (12.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.8/12.8 MB 47.9 MB/s eta 0:00:00 0:00:01
# Installing collected packages: en-core-web-sm
# Successfully installed en-core-web-sm-3.8.0
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')

# %% [markdown]
# ## 8. POS similarity functions

# %%
import spacy
from typing import List, Dict
from collections import Counter
import numpy as np

# Load the English language model
nlp = spacy.load("en_core_web_sm")

def get_pos_sequence(text):
    """Extracts the POS tag sequence from a given text."""
    doc = nlp(text)
    return [token.pos_ for token in doc]

def compare_pos_sequences(user_text, ai_text):
    """Compares POS tag sequences from user and AI text."""
    user_pos = get_pos_sequence(user_text)
    ai_pos = get_pos_sequence(ai_text)
    return {"user_pos": user_pos, "ai_pos": ai_pos}

def get_pos_frequencies(text):
    """Calculates the frequency of each POS tag in the given text."""
    pos_tags = get_pos_sequence(text)
    return dict(Counter(pos_tags))

def compare_pos_frequencies(user_text, ai_text):
    """Compares POS tag frequencies between user and AI text."""
    user_freq = get_pos_frequencies(user_text)
    ai_freq = get_pos_frequencies(ai_text)
    return {"user_freq": user_freq, "ai_freq": ai_freq}

# %%
pip install spacy
# Out:
# Collecting spacy
#   Using cached spacy-3.8.4-cp312-cp312-macosx_11_0_arm64.whl.metadata (27 kB)
# Collecting spacy-legacy<3.1.0,>=3.0.11 (from spacy)
#   Downloading spacy_legacy-3.0.12-py2.py3-none-any.whl.metadata (2.8 kB)
# Collecting spacy-loggers<2.0.0,>=1.0.0 (from spacy)
#   Downloading spacy_loggers-1.0.5-py3-none-any.whl.metadata (23 kB)
# Collecting murmurhash<1.1.0,>=0.28.0 (from spacy)
#   Downloading murmurhash-1.0.12-cp312-cp312-macosx_11_0_arm64.whl.metadata (2.1 kB)
# Collecting cymem<2.1.0,>=2.0.2 (from spacy)
#   Downloading cymem-2.0.11-cp312-cp312-macosx_11_0_arm64.whl.metadata (8.5 kB)
# Collecting preshed<3.1.0,>=3.0.2 (from spacy)
#   Downloading preshed-3.0.9-cp312-cp312-macosx_11_0_arm64.whl.metadata (2.2 kB)
# Collecting thinc<8.4.0,>=8.3.4 (from spacy)
#   Downloading thinc-8.3.4-cp312-cp312-macosx_11_0_arm64.whl.metadata (15 kB)
# Collecting wasabi<1.2.0,>=0.9.1 (from spacy)
#   Downloading wasabi-1.1.3-py3-none-any.whl.metadata (28 kB)
# Collecting srsly<3.0.0,>=2.4.3 (from spacy)
#   Downloading srsly-2.5.1-cp312-cp312-macosx_11_0_arm64.whl.metadata (19 kB)
# Collecting catalogue<2.1.0,>=2.0.6 (from spacy)
#   Downloading catalogue-2.0.10-py3-none-any.whl.metadata (14 kB)
# Collecting weasel<0.5.0,>=0.1.0 (from spacy)
#   Downloading weasel-0.4.1-py3-none-any.whl.metadata (4.6 kB)
# Collecting typer<1.0.0,>=0.3.0 (from spacy)
#   Downloading typer-0.15.2-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /opt/anaconda3/lib/python3.12/site-packages (from spacy) (4.66.5)
# Requirement already satisfied: numpy>=1.19.0 in /opt/anaconda3/lib/python3.12/site-packages (from spacy) (1.26.4)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /opt/anaconda3/lib/python3.12/site-packages (from spacy) (2.32.3)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /opt/anaconda3/lib/python3.12/site-packages (from spacy) (2.8.2)
# Requirement already satisfied: jinja2 in /opt/anaconda3/lib/python3.12/site-packages (from spacy) (3.1.4)
# Requirement already satisfied: setuptools in /opt/anaconda3/lib/python3.12/site-packages (from spacy) (75.1.0)
# Requirement already satisfied: packaging>=20.0 in /opt/anaconda3/lib/python3.12/site-packages (from spacy) (24.1)
# Collecting langcodes<4.0.0,>=3.2.0 (from spacy)
#   Downloading langcodes-3.5.0-py3-none-any.whl.metadata (29 kB)
# Collecting language-data>=1.2 (from langcodes<4.0.0,>=3.2.0->spacy)
#   Downloading language_data-1.3.0-py3-none-any.whl.metadata (4.3 kB)
# Requirement already satisfied: annotated-types>=0.4.0 in /opt/anaconda3/lib/python3.12/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (0.6.0)
# Requirement already satisfied: pydantic-core==2.20.1 in /opt/anaconda3/lib/python3.12/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (2.20.1)
# Requirement already satisfied: typing-extensions>=4.6.1 in /opt/anaconda3/lib/python3.12/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (4.11.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/anaconda3/lib/python3.12/site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/lib/python3.12/site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/anaconda3/lib/python3.12/site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/lib/python3.12/site-packages (from requests<3.0.0,>=2.13.0->spacy) (2024.12.14)
# Collecting blis<1.3.0,>=1.2.0 (from thinc<8.4.0,>=8.3.4->spacy)
#   Downloading blis-1.2.0-cp312-cp312-macosx_11_0_arm64.whl.metadata (7.7 kB)
# Collecting confection<1.0.0,>=0.0.1 (from thinc<8.4.0,>=8.3.4->spacy)
#   Downloading confection-0.1.5-py3-none-any.whl.metadata (19 kB)
# Requirement already satisfied: click>=8.0.0 in /opt/anaconda3/lib/python3.12/site-packages (from typer<1.0.0,>=0.3.0->spacy) (8.1.7)
# Collecting shellingham>=1.3.0 (from typer<1.0.0,>=0.3.0->spacy)
#   Using cached shellingham-1.5.4-py2.py3-none-any.whl.metadata (3.5 kB)
# Requirement already satisfied: rich>=10.11.0 in /opt/anaconda3/lib/python3.12/site-packages (from typer<1.0.0,>=0.3.0->spacy) (13.7.1)
# Collecting cloudpathlib<1.0.0,>=0.7.0 (from weasel<0.5.0,>=0.1.0->spacy)
#   Downloading cloudpathlib-0.20.0-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: smart-open<8.0.0,>=5.2.1 in /opt/anaconda3/lib/python3.12/site-packages (from weasel<0.5.0,>=0.1.0->spacy) (5.2.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/anaconda3/lib/python3.12/site-packages (from jinja2->spacy) (2.1.3)
# Collecting marisa-trie>=1.1.0 (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy)
#   Downloading marisa_trie-1.2.1-cp312-cp312-macosx_11_0_arm64.whl.metadata (9.0 kB)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /opt/anaconda3/lib/python3.12/site-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /opt/anaconda3/lib/python3.12/site-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (2.15.1)
# Requirement already satisfied: mdurl~=0.1 in /opt/anaconda3/lib/python3.12/site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (0.1.0)
# Downloading spacy-3.8.4-cp312-cp312-macosx_11_0_arm64.whl (6.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.0/6.0 MB 72.2 MB/s eta 0:00:00
# Downloading catalogue-2.0.10-py3-none-any.whl (17 kB)
# Downloading cymem-2.0.11-cp312-cp312-macosx_11_0_arm64.whl (42 kB)
# Downloading langcodes-3.5.0-py3-none-any.whl (182 kB)
# Downloading murmurhash-1.0.12-cp312-cp312-macosx_11_0_arm64.whl (27 kB)
# Downloading preshed-3.0.9-cp312-cp312-macosx_11_0_arm64.whl (128 kB)
# Downloading spacy_legacy-3.0.12-py2.py3-none-any.whl (29 kB)
# Downloading spacy_loggers-1.0.5-py3-none-any.whl (22 kB)
# Downloading srsly-2.5.1-cp312-cp312-macosx_11_0_arm64.whl (634 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 634.7/634.7 kB 31.0 MB/s eta 0:00:00
# Downloading thinc-8.3.4-cp312-cp312-macosx_11_0_arm64.whl (761 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 761.0/761.0 kB 42.3 MB/s eta 0:00:00
# Downloading typer-0.15.2-py3-none-any.whl (45 kB)
# Downloading wasabi-1.1.3-py3-none-any.whl (27 kB)
# Downloading weasel-0.4.1-py3-none-any.whl (50 kB)
# Downloading blis-1.2.0-cp312-cp312-macosx_11_0_arm64.whl (1.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 62.6 MB/s eta 0:00:00
# Downloading cloudpathlib-0.20.0-py3-none-any.whl (52 kB)
# Downloading confection-0.1.5-py3-none-any.whl (35 kB)
# Downloading language_data-1.3.0-py3-none-any.whl (5.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.4/5.4 MB 74.3 MB/s eta 0:00:00
# Using cached shellingham-1.5.4-py2.py3-none-any.whl (9.8 kB)
# Downloading marisa_trie-1.2.1-cp312-cp312-macosx_11_0_arm64.whl (174 kB)
# Installing collected packages: cymem, wasabi, spacy-loggers, spacy-legacy, shellingham, murmurhash, marisa-trie, cloudpathlib, catalogue, blis, srsly, preshed, language-data, typer, langcodes, confection, weasel, thinc, spacy
# Successfully installed blis-1.2.0 catalogue-2.0.10 cloudpathlib-0.20.0 confection-0.1.5 cymem-2.0.11 langcodes-3.5.0 language-data-1.3.0 marisa-trie-1.2.1 murmurhash-1.0.12 preshed-3.0.9 shellingham-1.5.4 spacy-3.8.4 spacy-legacy-3.0.12 spacy-loggers-1.0.5 srsly-2.5.1 thinc-8.3.4 typer-0.15.2 wasabi-1.1.3 weasel-0.4.1
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# Function to calculate cosine similarity between POS of texts

# %%
from sklearn.metrics.pairwise import cosine_similarity
def cosine_similarity_pos(pos1, pos2):
    """Computes cosine similarity between POS tag frequency vectors."""
    pos1_freq = Counter(pos1)
    pos2_freq = Counter(pos2)

    # Create a sorted list of all POS tags in both texts
    all_tags = sorted(set(pos1_freq.keys()) | set(pos2_freq.keys()))

    # Convert frequency dictionaries into vectors
    vec1 = np.array([pos1_freq.get(tag, 0) for tag in all_tags]).reshape(1, -1)
    vec2 = np.array([pos2_freq.get(tag, 0) for tag in all_tags]).reshape(1, -1)

    # Compute cosine similarity
    return cosine_similarity(vec1, vec2)[0][0]

# %% [markdown]
# ## 7. Compute Coherence, Creativity

# %%
# Function to compute coherence
from sentence_transformers import SentenceTransformer, util

model = SentenceTransformer('all-MiniLM-L6-v2')

def compute_coherence(suggestion, context):
    embeddings = model.encode([suggestion, context])
    similarity = util.cos_sim(embeddings[0], embeddings[1]).item()  # Convert tensor to float
    return similarity
# Out:
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/10.7k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/350 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# 1_Pooling%2Fconfig.json:   0%|          | 0.00/190 [00:00<?, ?B/s]

# %%
# Adapted from Lu et al. 2024
import os
import nltk
import json
import time
import requests
import argparse
import numpy as np
from tqdm import tqdm
from typing import List, Callable
from dataclasses import dataclass
from unidecode import unidecode
from sacremoses import MosesDetokenizer
from transformers import AutoTokenizer

md = MosesDetokenizer(lang='en')
API_URL = 'https://api.infini-gram.io/'
HF_TOKEN = "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"
tokenizer = AutoTokenizer.from_pretrained("meta-llama/Llama-2-7b-hf", token=HF_TOKEN,
                                          add_bos_token=False, add_eos_token=False)
@dataclass
class Document:
    doc_id: str
    tokens: List[str]

@dataclass
class Span:
    start_index: int
    end_index: int
    span_text: str
    occurrence: int

class Hypothesis:
    def __init__(self, target_doc: Document, min_ngram: int) -> None:
        self.target_doc = target_doc
        self.min_ngram = min_ngram
        self.spans = []
        self.finished = False

    def add_span(self, new_span: Span) -> None:
        self.spans.append(new_span)
        if new_span.end_index >= len(self.target_doc.tokens):
            self.finished = True

    def replace_span(self, new_span: Span) -> None:
        self.spans = self.spans[:-1] + [new_span]
        if new_span.end_index >= len(self.target_doc.tokens):
            self.finished = True

    def get_score(self) -> float:
        if not self.spans:
            return 0.0
        progress_len = self.spans[-1].end_index if not self.finished else len(self.target_doc.tokens)
        flags = [False] * progress_len
        for span in self.spans:
            span_length = span.end_index - span.start_index
            flags[span.start_index:span.end_index] = [True] * span_length
        coverage = sum(flags) / len(flags)
        return coverage

    def format_span(self) -> str:
        return ' | '.join([s.span_text for s in self.spans])

    def __hash__(self) -> int:
        return hash(self.format_span())

    def __eq__(self, other) -> bool:
        if isinstance(other, Hypothesis):
            return self.format_span() == other.format_span()
        return NotImplemented

    def get_avg_span_len(self) -> float:
        if not self.spans:
            return 0.0
        span_lengths = [s.end_index - s.start_index for s in self.spans]
        return sum(span_lengths) / len(span_lengths)

    def export_json(self) -> dict:
        matched_spans = [{
            'start_index': s.start_index,
            'end_index': s.end_index,
            'span_text': s.span_text,
            'occurrence': s.occurrence
        } for s in self.spans]
        return {
            'matched_spans': matched_spans,
            'coverage': self.get_score(),
            'avg_span_len': self.get_avg_span_len(),
        }

def find_exact_match(detokenize: Callable, doc: Document, min_ngram: int) -> dict:
    hypothesis = Hypothesis(doc, min_ngram)
    first_pointer, second_pointer = 0, min_ngram
    while second_pointer <= len(doc.tokens):
        span_text = detokenize(doc.tokens[first_pointer:second_pointer])
        request_data = {
            'corpus': 'v4_rpj_llama_s4',
            'engine': 'c++',
            'query_type': 'count',
            'query': span_text,
        }
        search_result = requests.post(API_URL, json=request_data).json()
        occurrence = search_result.get('count', 0)

        if occurrence:
            matched_span = Span(
                start_index=first_pointer,
                end_index=second_pointer,
                span_text=span_text,
                occurrence=occurrence
            )
            if not hypothesis.spans:
                hypothesis.add_span(matched_span)
            else:
                last_span = hypothesis.spans[-1]
                if matched_span.start_index <= last_span.start_index and last_span.end_index <= matched_span.end_index:
                    hypothesis.replace_span(matched_span)
                else:
                    hypothesis.add_span(matched_span)
            second_pointer += 1

            # print("***************************************************************************************************")
            # print(hypothesis.format_span())
            # print(f'score: {hypothesis.get_score():.4f}  avg_span_length: {hypothesis.get_avg_span_len()}')
            # print("***************************************************************************************************")
        else:
            if second_pointer - first_pointer > min_ngram:
                first_pointer += 1
            elif second_pointer - first_pointer == min_ngram:
                first_pointer += 1
                second_pointer += 1
            else:
                raise ValueError("Invalid state in span detection.")

    hypothesis.finished = True
    return hypothesis.export_json()

def process_text(text: str, min_ngram: int = 6, lm_tokenizer: bool = False) -> dict:
    # Choose the appropriate tokenizer/detokenizer.
    if not lm_tokenizer:
        tokenize_func = lambda x: nltk.tokenize.casual.casual_tokenize(x)
        detokenize = lambda tokens: md.detokenize(tokens)
    else:
        tokenize_func = lambda x: tokenizer.tokenize(x)
        detokenize = lambda tokens: tokenizer.decode(tokenizer.convert_tokens_to_ids(tokens))

    # Preprocess and tokenize the plain text.
    processed_text = unidecode(text)
    tokens = tokenize_func(processed_text)

    if len(tokens) <= min_ngram:
        raise ValueError("Input text is too short for the specified min_ngram.")

    # Build a Document and perform the exact match search.
    doc = Document(doc_id="input_text", tokens=tokens)
    result = find_exact_match(detokenize, doc, min_ngram)
    return result

print (process_text("I'm the best in the world, laughing out loud.")['coverage'])
# Out:
# tokenizer_config.json:   0%|          | 0.00/776 [00:00<?, ?B/s]
# tokenizer.model:   0%|          | 0.00/500k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.84M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/414 [00:00<?, ?B/s]
# 0.6363636363636364

# %%
import spacy
from collections import deque

# Load spaCy model
nlp = spacy.load("en_core_web_sm")

def get_parse_tree_depth(sent):
    """
    Calculate parse tree depth for a sentence using a BFS
    starting from the root token.
    """
    roots = [token for token in sent if token.head == token]
    if not roots:
        return 0
    root = roots[0]
    max_depth = 0
    depths = {root: 0}
    queue = deque([root])

    while queue:
        node = queue.popleft()
        for child in node.children:
            depths[child] = depths[node] + 1
            max_depth = max(max_depth, depths[child])
            queue.append(child)
    return max_depth

def count_subordinate_clauses(doc):
    """
    Count subordinate clauses by looking for tokens with dependency labels
    typically marking clause boundaries:
      - 'mark' (subordinating conjunctions),
      - 'advcl' (adverbial clauses), and
      - 'ccomp' (clausal complements).
    """
    count = 0
    for token in doc:
        if token.dep_ in {"mark", "advcl", "ccomp"}:
            count += 1
    return count

def count_passive_sentences(doc):
    """
    Identify and count passive sentences. A sentence is considered passive
    if it contains any token with the dependency 'nsubjpass'.
    """
    passive_count = 0
    for sent in doc.sents:
        if any(token.dep_ == "nsubjpass" for token in sent):
            passive_count += 1
    return passive_count

def syntactic_complexity(text, d_max=10, max_subordinate_per_sentence=2):
    """
    Calculate a normalized syntactic complexity score in the range [0,1].
    It is very knowledge-based.
    This function computes three components:
      1. Depth Component: Average parse tree depth normalized by d_max.
         The average is capped at d_max to avoid outlier effects.
      2. Subordinate Clause Component: The average number of subordinate clauses
         per sentence normalized by an assumed maximum (default=2).
      3. Passive Voice Component: The fraction of sentences exhibiting passive voice.

    The final score is the average of these three components.
    """
    doc = nlp(text)
    sentences = list(doc.sents)
    num_sentences = len(sentences)

    if num_sentences == 0:
        return 0.0

    # Depth Component
    total_depth = sum(get_parse_tree_depth(sent) for sent in sentences)
    avg_depth = total_depth / num_sentences
    depth_component = min(avg_depth, d_max) / d_max  # normalize to [0,1]

    # Subordinate Clause Component
    num_subordinate = count_subordinate_clauses(doc)
    subordinate_component = (num_subordinate / num_sentences) / max_subordinate_per_sentence
    subordinate_component = min(subordinate_component, 1.0)

    # Passive Voice Component
    passive_sentences = count_passive_sentences(doc)
    passive_component = passive_sentences / num_sentences  # already in [0,1]

    # Combine components equally to yield a final score between 0 and 1
    normalized_score = (depth_component + subordinate_component + passive_component) / 3.0
    return normalized_score

text = (
    "The old mansion, which had been abandoned for years, stood silent. Its walls, marked by time and neglect, told stories as if they were whispering. The garden was overgrown, and nature had reclaimed it, making it look like a scene from a forgotten fairy tale."
)

score = syntactic_complexity(text)
print("Normalized Syntactic Complexity Score:", score)
# Out:
# Normalized Syntactic Complexity Score: 0.5777777777777777

# %% [markdown]
# ## 8. Create Dataframe
# Creates the dataframe with user text, ai-suggestion, workerID, helpfulness metrics.

# %%
jsd_results = []

for path in paths:
    events = read_writing_session(path)

    if len(events) < 3000:
        user_texts = reconstruct_user_text(events)
        ai_suggestions = extract_selected_ai_suggestions(events)
        acceptance_status = extract_acceptance_status(events)

        # Extract matching path key
        path_key = os.path.basename(path).replace(".jsonl", "").replace("./coauthor-v1.0/","")
        worker_id = workerID.loc[workerID["session_id"] == path_key, "worker_id"].values[0]

        for user_text, ai_text, status in zip(user_texts, ai_suggestions, acceptance_status):
            if len(ai_text.split()) <= 6 or len(user_text.split()) <= 6:
                continue
            user_score, user_vector = get_emotion_vector(user_text)
            ai_score, ai_vector = get_emotion_vector(ai_text)

            jsd_similarity = similarity_jsd(user_vector, ai_vector)
            user_pos = get_pos_sequence(user_text)
            ai_pos = get_pos_sequence(ai_text)
            pos_similarity = cosine_similarity_pos(user_pos, ai_pos)

            # Compute coherence
            coherence_score = compute_coherence(ai_text, user_text)


            # Compute Syntactical Complexity and Coverage

            user_syn = syntactic_complexity(user_text)
            ai_syn = syntactic_complexity(ai_text)
            ai_coverage = process_text(ai_text)['coverage']
            # Store results
            jsd_results.append({
                "path": path,
                "workerID": worker_id,
                "user_text": user_text,
                "ai_suggestion": ai_text,
                "tone_similarity": jsd_similarity,
                "pos_similarity": pos_similarity,
                "coherence_score": coherence_score,
                "user_score": user_syn,
                "ai_score": ai_syn,
                "ai_coverage": ai_coverage,
                "acceptance_status": status
            })
# Out:
# Successfully read 3045 events in a writing session from ./coauthor-v1.0/e0435f4cf6fc435c872ffc5b66b66b0c.jsonl
# Successfully read 1989 events in a writing session from ./coauthor-v1.0/74517c6eb89c46fab708de3e3d7c53db.jsonl
# Successfully read 2008 events in a writing session from ./coauthor-v1.0/91e0856327a04acb8f366faea281f072.jsonl
# Successfully read 1576 events in a writing session from ./coauthor-v1.0/ba931f5050e7409ebba26e00d532cc7c.jsonl
# Successfully read 2115 events in a writing session from ./coauthor-v1.0/128bac319cb14dadaaf5c30c3a8ac5cb.jsonl
# Successfully read 1942 events in a writing session from ./coauthor-v1.0/fa68c16d925c4ec08cbb9e393982aca9.jsonl
# Successfully read 2682 events in a writing session from ./coauthor-v1.0/02a0a1349a8045bd969dfc3948ec4796.jsonl
# Successfully read 1445 events in a writing session from ./coauthor-v1.0/3b6e7a4c9d65411f9342254120abcde7.jsonl
# Successfully read 1968 events in a writing session from ./coauthor-v1.0/3969517100834dbc813b628a27fed790.jsonl
# Successfully read 2150 events in a writing session from ./coauthor-v1.0/994c929ac0db414cbb96423bb245eb7c.jsonl
# Successfully read 1418 events in a writing session from ./coauthor-v1.0/b24842bebbc045249f59a791912f491d.jsonl
# Successfully read 3572 events in a writing session from ./coauthor-v1.0/e34e7611bef74a0aafda89752af534f3.jsonl
# Successfully read 2560 events in a writing session from ./coauthor-v1.0/5773114053f147a69bd6790843ea4fd8.jsonl
# Successfully read 3321 events in a writing session from ./coauthor-v1.0/9d363533d9734263b3feda158f5cfb69.jsonl
# Successfully read 1369 events in a writing session from ./coauthor-v1.0/57f0dbe735624c44b58c67e78a31caa6.jsonl
# Successfully read 1741 events in a writing session from ./coauthor-v1.0/fb0562d64a314d2088af7d18ea7dc210.jsonl
# Successfully read 3259 events in a writing session from ./coauthor-v1.0/9154097557f84fe1862d1205b098b4ad.jsonl
# Successfully read 2210 events in a writing session from ./coauthor-v1.0/2ce71b3ded9340529f08b8ce0bc0a2d1.jsonl
# Successfully read 1275 events in a writing session from ./coauthor-v1.0/5f020c0bdea94db5aad0478ba02f2924.jsonl
# Successfully read 1892 events in a writing session from ./coauthor-v1.0/bc176a916d344af496f7bdbf408db4e9.jsonl
# Successfully read 2567 events in a writing session from ./coauthor-v1.0/df7ebb6fc93c419d84052f9579fa6e0a.jsonl
# Successfully read 2719 events in a writing session from ./coauthor-v1.0/9b439ea7aa404000a1e0ee118bdbfbd1.jsonl
# Successfully read 1870 events in a writing session from ./coauthor-v1.0/c9cb7242b4c44fdb97c5ecedb7d5cf4a.jsonl
# Successfully read 3391 events in a writing session from ./coauthor-v1.0/b21c00d7e32543f8a6e1b55574044733.jsonl
# Successfully read 1830 events in a writing session from ./coauthor-v1.0/423daa7fb2214d1093f73d4966240646.jsonl
# Successfully read 2094 events in a writing session from ./coauthor-v1.0/6a9dd4e609624942951409d15edb0ff3.jsonl
# Successfully read 1948 events in a writing session from ./coauthor-v1.0/73e1236fcc4f48d3ba4d264eb6ffe06e.jsonl
# Successfully read 1258 events in a writing session from ./coauthor-v1.0/1a05d6f6ae524b638b5e3ea491d3fc4d.jsonl
# Successfully read 2103 events in a writing session from ./coauthor-v1.0/093bf29840194d24ba2b828b3a6e04cd.jsonl
# Successfully read 1486 events in a writing session from ./coauthor-v1.0/8c884bfc6cad45cf9b9609a7acbb0bf7.jsonl
# Successfully read 571 events in a writing session from ./coauthor-v1.0/946720ae11b5468e858df027906f1063.jsonl
# Successfully read 1621 events in a writing session from ./coauthor-v1.0/3cfab79e841a41a7b6edf77e7b28886b.jsonl
# Successfully read 3306 events in a writing session from ./coauthor-v1.0/81f59f9cba194b04802bbeae51dc798c.jsonl
# Successfully read 1464 events in a writing session from ./coauthor-v1.0/01bc6cf8deb24d5e8877daac7cb4d086.jsonl
# Successfully read 875 events in a writing session from ./coauthor-v1.0/07dab80e78f24a8bb09384e9067719d0.jsonl
# Successfully read 2416 events in a writing session from ./coauthor-v1.0/2f57e9155477457aad589a7cc507cd68.jsonl
# Successfully read 1281 events in a writing session from ./coauthor-v1.0/6efda955ff5643aab9d94b60c4b1cdee.jsonl
# Successfully read 2008 events in a writing session from ./coauthor-v1.0/b6620ed18c174f708138abb59ade11ca.jsonl
# Successfully read 2338 events in a writing session from ./coauthor-v1.0/4fc378c03e0a49b6a9a2674ed809242d.jsonl
# Successfully read 3428 events in a writing session from ./coauthor-v1.0/aec86c4e50874219b34fc6bbebe815de.jsonl
# Successfully read 1589 events in a writing session from ./coauthor-v1.0/b93e342180e34c518e2ff42b2589a68e.jsonl
# Successfully read 1999 events in a writing session from ./coauthor-v1.0/b15c9dc0bbc1415dad0b1339d32903dd.jsonl
# Successfully read 1469 events in a writing session from ./coauthor-v1.0/a60c272551c6418a845424432fc4cc72.jsonl
# Successfully read 3202 events in a writing session from ./coauthor-v1.0/b5a9cacc2fc24fc583d5442b3c607278.jsonl
# Successfully read 1255 events in a writing session from ./coauthor-v1.0/ba5029002a8e486f98404e68e850a3b5.jsonl
# Successfully read 931 events in a writing session from ./coauthor-v1.0/8f7e2949da2c45e597b39ee6e3f85d84.jsonl
# Successfully read 1112 events in a writing session from ./coauthor-v1.0/38375f5155704d2d8509843e56ec029d.jsonl
# Successfully read 2078 events in a writing session from ./coauthor-v1.0/af35478b772442319c64d331bc779ed0.jsonl
# Successfully read 1697 events in a writing session from ./coauthor-v1.0/7edc4eee07cd44db9a01e28f1ef20064.jsonl
# Successfully read 1287 events in a writing session from ./coauthor-v1.0/1fd40d445a5f4fa6af359b4452866eb1.jsonl
# Successfully read 1383 events in a writing session from ./coauthor-v1.0/1b693f634f3047d6aa0bfafd486fcd51.jsonl
# Successfully read 1796 events in a writing session from ./coauthor-v1.0/14c0fb6353864b748f56af9aae22343c.jsonl
# Successfully read 1468 events in a writing session from ./coauthor-v1.0/04cb21c58e7845ae9eb740c4756731ed.jsonl
# Successfully read 2586 events in a writing session from ./coauthor-v1.0/4c9727b380f34b5baa3d4407f8d91656.jsonl
# Successfully read 2006 events in a writing session from ./coauthor-v1.0/3f08232e93af452cb4f47c0bc22a6980.jsonl
# Successfully read 1019 events in a writing session from ./coauthor-v1.0/a1e9b672e5814598a1ec37a8210b8c12.jsonl
# Successfully read 950 events in a writing session from ./coauthor-v1.0/3d6a7c48810349b4a145b117bd38afa9.jsonl
# Successfully read 2106 events in a writing session from ./coauthor-v1.0/057b11be0cbb400ea2cfda2cf75292b2.jsonl
# Successfully read 872 events in a writing session from ./coauthor-v1.0/8621bf6cd9e341bb80194d19d210b7e4.jsonl
# Successfully read 1502 events in a writing session from ./coauthor-v1.0/9500323928c249d5851b8e56a2362537.jsonl
# Successfully read 1340 events in a writing session from ./coauthor-v1.0/820a0ffa457343b2a3d1e69a48d604e8.jsonl
# Successfully read 2863 events in a writing session from ./coauthor-v1.0/96550fd2d40e46c1a430fe0c4e67000b.jsonl
# Successfully read 1447 events in a writing session from ./coauthor-v1.0/047e78f3d0a94ea4a3433d4358b53adf.jsonl
# Successfully read 2685 events in a writing session from ./coauthor-v1.0/df1fe58fe9244c8fbf1183f385d2112f.jsonl
# Successfully read 1672 events in a writing session from ./coauthor-v1.0/200b5a62bded44f6ba8320c117bee58a.jsonl
# Successfully read 1714 events in a writing session from ./coauthor-v1.0/3622a1e30581463fa5850f1f8325d26e.jsonl
# Successfully read 1285 events in a writing session from ./coauthor-v1.0/1a50c197cf564bf88f386197d1f279d9.jsonl
# Successfully read 1826 events in a writing session from ./coauthor-v1.0/ad4eeaa42cea40e7b278d61f1505ef7f.jsonl
# Successfully read 1399 events in a writing session from ./coauthor-v1.0/114dfaf5c4a0437880b6829c92b9dce8.jsonl
# Successfully read 2494 events in a writing session from ./coauthor-v1.0/272a45b11c944afcbf51b390caa3a6b0.jsonl
# Successfully read 1598 events in a writing session from ./coauthor-v1.0/bd54a50b118341678efa571079cae11e.jsonl
# Successfully read 1821 events in a writing session from ./coauthor-v1.0/927ad269b1a94de58c22285e806979e9.jsonl
# Successfully read 2460 events in a writing session from ./coauthor-v1.0/1869b9eca05c4d7bba240afdabbb72e5.jsonl
# Successfully read 1737 events in a writing session from ./coauthor-v1.0/8def8b4e1181424c8009e7c77cd1f1f5.jsonl
# Successfully read 1893 events in a writing session from ./coauthor-v1.0/fe677c513394449e987eb3ccce62d03c.jsonl
# Successfully read 1955 events in a writing session from ./coauthor-v1.0/fb5e90d056b14b128c73f0d7cd366304.jsonl
# Successfully read 1888 events in a writing session from ./coauthor-v1.0/ddb30c809dfe47f8b0d0c10147b240b4.jsonl
# Successfully read 3541 events in a writing session from ./coauthor-v1.0/07cea97c61b4495389f8e0c0faa076bd.jsonl
# Successfully read 2385 events in a writing session from ./coauthor-v1.0/35f5f0465417437f923efcd624af7502.jsonl
# Successfully read 2146 events in a writing session from ./coauthor-v1.0/6d7b66caeb974603a770490a4a83c38a.jsonl
# Successfully read 1415 events in a writing session from ./coauthor-v1.0/f0ca76b1be0648018bed5d7c436b46c1.jsonl
# Successfully read 1699 events in a writing session from ./coauthor-v1.0/3e1e3f82426c4b5682b3b315908dd8f8.jsonl
# Successfully read 1748 events in a writing session from ./coauthor-v1.0/12c0273868a84564a5f001c3c086f69f.jsonl
# Successfully read 1333 events in a writing session from ./coauthor-v1.0/86b1f1bb36bc4cc588e6dfc86d7a5bc4.jsonl
# Successfully read 481 events in a writing session from ./coauthor-v1.0/40321204ac204fc3b3aa443db377eeaf.jsonl
# Successfully read 1241 events in a writing session from ./coauthor-v1.0/f7156d363a5d45ea9f0171bc468277b7.jsonl
# Successfully read 1546 events in a writing session from ./coauthor-v1.0/f64a674b006c4fa6adaf1bba48049f6c.jsonl
# Successfully read 2497 events in a writing session from ./coauthor-v1.0/9b4461a4349f43b8b12dea3e34256caa.jsonl
# Successfully read 1644 events in a writing session from ./coauthor-v1.0/f5258cb106194b4ea243d3842e00b667.jsonl
# Successfully read 1986 events in a writing session from ./coauthor-v1.0/36eead66360847afba6dc9ebf6d99593.jsonl
# Successfully read 2038 events in a writing session from ./coauthor-v1.0/8c58982958c1470dbebaff31cb041f9e.jsonl
# Successfully read 2393 events in a writing session from ./coauthor-v1.0/a15863f8588b40cd8ba28a171471031f.jsonl
# Successfully read 2226 events in a writing session from ./coauthor-v1.0/3f0f0ddbc9dc46de8ca3622aa4f09119.jsonl
# Successfully read 1656 events in a writing session from ./coauthor-v1.0/05b655163b1e4e38b76c2785a0aea5bb.jsonl
# Successfully read 1462 events in a writing session from ./coauthor-v1.0/bb89b8b76a9847f9ba0d7e67fc4fc23e.jsonl
# Successfully read 1862 events in a writing session from ./coauthor-v1.0/68fd27f0d07a4a319c9f931331f16e2d.jsonl
# Successfully read 1106 events in a writing session from ./coauthor-v1.0/173cae0bcc714ba29bfeab4004d7fa85.jsonl
# Successfully read 1439 events in a writing session from ./coauthor-v1.0/c67b81a329e94a0095f9af21bd61adec.jsonl
# Successfully read 1333 events in a writing session from ./coauthor-v1.0/b7786334c02b44e8b062463726e43203.jsonl
# Successfully read 1352 events in a writing session from ./coauthor-v1.0/3a2ebf0908de4181a06d27b93f0ac07c.jsonl
# Successfully read 4580 events in a writing session from ./coauthor-v1.0/f3fd58f51d4a406ba6151b630e18dbac.jsonl
# Successfully read 2686 events in a writing session from ./coauthor-v1.0/9989ea7d26a94464a9d94f68bc7832e9.jsonl
# Successfully read 2269 events in a writing session from ./coauthor-v1.0/f326178e52c34b5b97911cbe8f9c58ba.jsonl
# Successfully read 2213 events in a writing session from ./coauthor-v1.0/9b1d2408672e4e8595c322bc04146995.jsonl
# Successfully read 1189 events in a writing session from ./coauthor-v1.0/7b0cd9f4cae6467ca5bcd8c5e0aed9e6.jsonl
# Successfully read 841 events in a writing session from ./coauthor-v1.0/12c7f30c5ba146e2a880fac46bc1e27c.jsonl
# Successfully read 919 events in a writing session from ./coauthor-v1.0/a6fdd2b52268416d9b3ebf015fa82e18.jsonl
# Successfully read 3744 events in a writing session from ./coauthor-v1.0/9d55ac3f8bce45c5a4325b2befeba8f4.jsonl
# Successfully read 1609 events in a writing session from ./coauthor-v1.0/9c4c0d44fdeb452aaada54d0d89e7ce5.jsonl
# Successfully read 1205 events in a writing session from ./coauthor-v1.0/0bad9cbc52854c13a1b982195f7face2.jsonl
# Successfully read 2466 events in a writing session from ./coauthor-v1.0/1bf54732c8a34ff6bc71dcfe7357629a.jsonl
# Successfully read 3555 events in a writing session from ./coauthor-v1.0/b47d3c5973494f02af1668b926a7210e.jsonl
# Successfully read 1757 events in a writing session from ./coauthor-v1.0/818ee877dd3340e1814bce6e34477cef.jsonl
# Successfully read 953 events in a writing session from ./coauthor-v1.0/971b30521fb149d88af88aa7b686c2af.jsonl
# Successfully read 1576 events in a writing session from ./coauthor-v1.0/8558c2d306614fcfb3ae117e60204277.jsonl
# Successfully read 2953 events in a writing session from ./coauthor-v1.0/322cc9be91574818ae2811e740e7d142.jsonl
# Successfully read 1343 events in a writing session from ./coauthor-v1.0/a5dee567f6554c59bb8fafd85f547c22.jsonl
# Successfully read 1422 events in a writing session from ./coauthor-v1.0/e2ccab5b997f4aa19f39ffdb86be4151.jsonl
# Successfully read 2346 events in a writing session from ./coauthor-v1.0/0a6500a997e24468a743b34eda6be51e.jsonl
# Successfully read 2935 events in a writing session from ./coauthor-v1.0/4c08908581b54f46b00f0fdcef5fd3e4.jsonl
# Successfully read 1367 events in a writing session from ./coauthor-v1.0/96dd69eab5d846999c72d9b89734f6ac.jsonl
# Successfully read 1817 events in a writing session from ./coauthor-v1.0/0b75e34df86b4f729dbf23843db91112.jsonl
# Successfully read 1530 events in a writing session from ./coauthor-v1.0/ec89045037c142869afb5fad66c0c912.jsonl
# Successfully read 2150 events in a writing session from ./coauthor-v1.0/6f952927ae564d28bf573199e132ba66.jsonl
# Successfully read 1193 events in a writing session from ./coauthor-v1.0/e1f3635407a34cada54aafa852bcb52d.jsonl
# Successfully read 2823 events in a writing session from ./coauthor-v1.0/a07f20a8e58545c78b7b6436c126be7d.jsonl
# Successfully read 1221 events in a writing session from ./coauthor-v1.0/8610d3166aea4491b673112459745fc1.jsonl
# Successfully read 759 events in a writing session from ./coauthor-v1.0/c88c771b282d49af9c406582462da7a4.jsonl
# Successfully read 1559 events in a writing session from ./coauthor-v1.0/6861c7f0f19645ffb563275d11fad363.jsonl
# Successfully read 1046 events in a writing session from ./coauthor-v1.0/5001633aeeef432bae4d36268e3c7be6.jsonl
# Successfully read 1803 events in a writing session from ./coauthor-v1.0/07c5099d0eb24fb29da557733ed48f62.jsonl
# Successfully read 1209 events in a writing session from ./coauthor-v1.0/cf17210c31294194a0bf3e3a851a34ea.jsonl
# Successfully read 804 events in a writing session from ./coauthor-v1.0/2404074432c445018ff2b9f2b6ff89f4.jsonl
# Successfully read 2807 events in a writing session from ./coauthor-v1.0/b4134879f6494953bfca7456a0bc8341.jsonl
# Successfully read 2675 events in a writing session from ./coauthor-v1.0/e40238fb39514ae8a0719094d7337200.jsonl
# Successfully read 2257 events in a writing session from ./coauthor-v1.0/09644506674341f5b14e0d62c88ee70a.jsonl
# Successfully read 1477 events in a writing session from ./coauthor-v1.0/41d8a6e73a1e4df588aebd0ad14d8da1.jsonl
# Successfully read 1291 events in a writing session from ./coauthor-v1.0/4d64b8adb8544d60beaf585c83747e97.jsonl
# Successfully read 2874 events in a writing session from ./coauthor-v1.0/22a12c79a5914030aea6e0aa6d5edefe.jsonl
# Successfully read 1435 events in a writing session from ./coauthor-v1.0/47dff3bdc673494296ba42b16fec93fd.jsonl
# Successfully read 2655 events in a writing session from ./coauthor-v1.0/a96faa69af9e4ad4a252760ed12177aa.jsonl
# Successfully read 1266 events in a writing session from ./coauthor-v1.0/de90bdd73b72426daacc29cd1e1a2e97.jsonl
# Successfully read 1817 events in a writing session from ./coauthor-v1.0/050118bfac954920a524e7070132690b.jsonl
# Successfully read 1341 events in a writing session from ./coauthor-v1.0/fa039fa4741a4a53a7afa9ed1deac769.jsonl
# Successfully read 1051 events in a writing session from ./coauthor-v1.0/aea2e89578b3408983027d4f02ac76e6.jsonl
# Successfully read 1430 events in a writing session from ./coauthor-v1.0/dcb6bb7ac50740b49deae5bf9a0dc942.jsonl
# Successfully read 708 events in a writing session from ./coauthor-v1.0/5b6d31f421474c3483b1bd08227ff95d.jsonl
# Successfully read 2159 events in a writing session from ./coauthor-v1.0/e1bbde599aba419990efb136ec4ece38.jsonl
# Successfully read 1587 events in a writing session from ./coauthor-v1.0/ac909f8258ae4869b1011f700bbe17a9.jsonl
# Successfully read 2421 events in a writing session from ./coauthor-v1.0/dc2078ed9a2d4ebd84853c014639bd1f.jsonl
# Successfully read 1894 events in a writing session from ./coauthor-v1.0/0cb1f752dd254646830cf016f27b9f4f.jsonl
# Successfully read 2056 events in a writing session from ./coauthor-v1.0/126ae6528ba141a58f932a3ed097b47e.jsonl
# Successfully read 1951 events in a writing session from ./coauthor-v1.0/bad20cdce8404ef3b6992ae8758105d2.jsonl
# Successfully read 1797 events in a writing session from ./coauthor-v1.0/69b4d60dbea24e83a939dbef50497919.jsonl
# Successfully read 1892 events in a writing session from ./coauthor-v1.0/7062d62b58b64877aab1d5e95b927616.jsonl
# Successfully read 1375 events in a writing session from ./coauthor-v1.0/6f0c5bb458394a8d82d5d00886ffa92d.jsonl
# Successfully read 745 events in a writing session from ./coauthor-v1.0/75ca76d5d28b411098cc9819cb5d7b56.jsonl
# Successfully read 1531 events in a writing session from ./coauthor-v1.0/80624eb1f1d241e8b1fa4cdc70d43f0a.jsonl
# Successfully read 2071 events in a writing session from ./coauthor-v1.0/ed07606664fb45718dc42629cb072c1b.jsonl
# Successfully read 1672 events in a writing session from ./coauthor-v1.0/85bb144c94404f85ad2931edf1bcb8ae.jsonl
# Successfully read 934 events in a writing session from ./coauthor-v1.0/99dcceb9d7394bd1986fbf3572b3efcd.jsonl
# Successfully read 1110 events in a writing session from ./coauthor-v1.0/4ae07eece3a740de9b77f65ae67a10ad.jsonl
# Successfully read 1554 events in a writing session from ./coauthor-v1.0/685d08c3809e4d6da38d222976bcab17.jsonl
# Successfully read 1666 events in a writing session from ./coauthor-v1.0/4503b999b72848f396258761c04cc7e8.jsonl
# Successfully read 2559 events in a writing session from ./coauthor-v1.0/8288555e033840c3a745e220afdb4aa6.jsonl
# Successfully read 1667 events in a writing session from ./coauthor-v1.0/dcf08dcc251f48109e68b46ffc0561d6.jsonl
# Successfully read 1454 events in a writing session from ./coauthor-v1.0/bb00c5e393af4908b576fa3a86b6fd01.jsonl
# Successfully read 1474 events in a writing session from ./coauthor-v1.0/8db57b4ba7e048a9bf984a13233f3cf9.jsonl
# Successfully read 1267 events in a writing session from ./coauthor-v1.0/ed151ac677724c7fbd32f85db77710a2.jsonl
# Successfully read 1194 events in a writing session from ./coauthor-v1.0/bf739551dea348c48635d2fbabb51ed3.jsonl
# Successfully read 1529 events in a writing session from ./coauthor-v1.0/5fc3814b137b410cab4a738f50e91ad8.jsonl
# Successfully read 1540 events in a writing session from ./coauthor-v1.0/484eba21615341fab99300bfe20873fb.jsonl
# Successfully read 2085 events in a writing session from ./coauthor-v1.0/29001da80acb414d8683c660e2e091f2.jsonl
# Successfully read 2246 events in a writing session from ./coauthor-v1.0/dda6cf6e80e74a32b62d03db6c25859c.jsonl
# Successfully read 1457 events in a writing session from ./coauthor-v1.0/ffe94583242c4ffca4b1546bb39ba5c2.jsonl
# Successfully read 1663 events in a writing session from ./coauthor-v1.0/1e93ad6e64e4478886b3fc31bef6a960.jsonl
# Successfully read 1954 events in a writing session from ./coauthor-v1.0/afa0f80124e94b3b9793b29f814765c4.jsonl
# Successfully read 1934 events in a writing session from ./coauthor-v1.0/a2ae7a28141944dda986c3124ce58184.jsonl
# Successfully read 904 events in a writing session from ./coauthor-v1.0/93743bc8b6f94308881cff7cf90ad421.jsonl
# Successfully read 2453 events in a writing session from ./coauthor-v1.0/758b76b82ccf413aa93fd4d74624d288.jsonl
# Successfully read 1957 events in a writing session from ./coauthor-v1.0/ab5f8507e06746248ff59dd64d84e414.jsonl
# Successfully read 2246 events in a writing session from ./coauthor-v1.0/77cae115ed8349dbad550de12e5858c1.jsonl
# Successfully read 1937 events in a writing session from ./coauthor-v1.0/2f48900f757c47129a7cbf00d6130ab8.jsonl
# Successfully read 1375 events in a writing session from ./coauthor-v1.0/75297fb95d624e0fbc4f88c114a790e7.jsonl
# Successfully read 1707 events in a writing session from ./coauthor-v1.0/fc53ee7c7b1c4ad1886004483d6f3184.jsonl
# Successfully read 716 events in a writing session from ./coauthor-v1.0/40dce3e97526456ba66fa9765621ad70.jsonl
# Successfully read 1867 events in a writing session from ./coauthor-v1.0/67e2ebb79ef7428db8828883d135c55f.jsonl
# Successfully read 1403 events in a writing session from ./coauthor-v1.0/5221640d7c074d4a88f42e3891135350.jsonl
# Successfully read 2230 events in a writing session from ./coauthor-v1.0/cb3f032b7da641ef8ae12507ded9ee10.jsonl
# Successfully read 1935 events in a writing session from ./coauthor-v1.0/2f07a39c7b1848559d1f4786591771ba.jsonl
# Successfully read 1857 events in a writing session from ./coauthor-v1.0/dd0cbba1431349d985aca86e9e27359d.jsonl
# Successfully read 1172 events in a writing session from ./coauthor-v1.0/fd2ec09a682148418ea610817afcc79a.jsonl
# Successfully read 1307 events in a writing session from ./coauthor-v1.0/dca80ac7cfd148638a9c0f4b027f720a.jsonl
# Successfully read 1397 events in a writing session from ./coauthor-v1.0/00d39011efcb4533ab12076801f74f42.jsonl
# Successfully read 2102 events in a writing session from ./coauthor-v1.0/434f519e8863442f810796865db83047.jsonl
# Successfully read 1045 events in a writing session from ./coauthor-v1.0/46be40f9d65c4a8f8d924ac992f81376.jsonl
# Successfully read 1353 events in a writing session from ./coauthor-v1.0/6ccf934ffb284b76b9fa7e57ecabd06b.jsonl
# Successfully read 2052 events in a writing session from ./coauthor-v1.0/a6dd76d59f0a4cf0a6fdc4455fa4b639.jsonl
# Successfully read 1673 events in a writing session from ./coauthor-v1.0/551833edecbb48a9a13b5498cadd6346.jsonl
# Successfully read 1144 events in a writing session from ./coauthor-v1.0/0fe679b3bb1a472bb1d375c1c58e3687.jsonl
# Successfully read 2758 events in a writing session from ./coauthor-v1.0/74c7e84ad70d40ca97fa859664465bee.jsonl
# Successfully read 2366 events in a writing session from ./coauthor-v1.0/cbbfa156a608439c999233f7b05b9821.jsonl
# Successfully read 1285 events in a writing session from ./coauthor-v1.0/a9feecdb84e14399936bbbe1eb2bbfd7.jsonl
# Successfully read 1039 events in a writing session from ./coauthor-v1.0/1666138deed446cdaa2afc26f72aa18b.jsonl
# Successfully read 1420 events in a writing session from ./coauthor-v1.0/30e1d495e4e04d49b8b0a9cb6e193500.jsonl
# Successfully read 2421 events in a writing session from ./coauthor-v1.0/72b49bf3c2434ea498475566e09690fb.jsonl
# Successfully read 3411 events in a writing session from ./coauthor-v1.0/ac6634d8cd064dcb84b08c0eed768c3c.jsonl
# Successfully read 950 events in a writing session from ./coauthor-v1.0/a59321f59eeb459da6a427267afefb9b.jsonl
# Successfully read 1606 events in a writing session from ./coauthor-v1.0/2f8c2905bd764dd1a70ed96115e75edb.jsonl
# Successfully read 1209 events in a writing session from ./coauthor-v1.0/b7f82fbb0ba3481884581b9b0ba571a2.jsonl
# Successfully read 856 events in a writing session from ./coauthor-v1.0/d1c88e2180184f86ae24fb566073920a.jsonl
# Successfully read 1910 events in a writing session from ./coauthor-v1.0/23b4bbf06990474a9607178c5e4c95a9.jsonl
# Successfully read 2686 events in a writing session from ./coauthor-v1.0/3be583425f4c4656a906a036b13e963e.jsonl
# Successfully read 2271 events in a writing session from ./coauthor-v1.0/8d145264baaf4220b2848a60447cfd05.jsonl
# Successfully read 1024 events in a writing session from ./coauthor-v1.0/b420f1799193446cb60c42a4cfc5053b.jsonl
# Successfully read 1876 events in a writing session from ./coauthor-v1.0/54c597f302a9404caab702a8499b8aa0.jsonl
# Successfully read 1891 events in a writing session from ./coauthor-v1.0/153d73ea68dc4323af5341ce6c51ea73.jsonl
# Successfully read 2323 events in a writing session from ./coauthor-v1.0/8d4bdb014d5f4a919735ff5a928176b5.jsonl
# Successfully read 2455 events in a writing session from ./coauthor-v1.0/11d219390dd847a9809092f91a1416d4.jsonl
# Successfully read 1632 events in a writing session from ./coauthor-v1.0/4087251840494e2f85eefbc4537add1c.jsonl
# Successfully read 2121 events in a writing session from ./coauthor-v1.0/a083b39bf3744dcb9cf43434322dbe1b.jsonl
# Successfully read 2583 events in a writing session from ./coauthor-v1.0/c28981a2c8af4ccdb127d3a74ca363ac.jsonl
# Successfully read 1335 events in a writing session from ./coauthor-v1.0/3b62a2036d2643faa4590b94c3fb0d35.jsonl
# Successfully read 1907 events in a writing session from ./coauthor-v1.0/acfb5f25d1ce43cab27b6e945b14dd1e.jsonl
# Successfully read 653 events in a writing session from ./coauthor-v1.0/61365e6b13164a04b33e0c5b18aa73c8.jsonl
# Successfully read 1940 events in a writing session from ./coauthor-v1.0/66205a33c6084ec39f3ca9ebd2c0cfee.jsonl
# Successfully read 2517 events in a writing session from ./coauthor-v1.0/3d19d3770396446bb568be0852f3bcd4.jsonl
# Successfully read 1951 events in a writing session from ./coauthor-v1.0/266f0df3fa994ce1b0b8b37da8169d62.jsonl
# Successfully read 2501 events in a writing session from ./coauthor-v1.0/83abfb13942f491b9de32bfcc1c3dc47.jsonl
# Successfully read 1468 events in a writing session from ./coauthor-v1.0/112e8b0e22094577ae3e513d70f78432.jsonl
# Successfully read 1247 events in a writing session from ./coauthor-v1.0/08b1a2012f4d4115b56cc8231449ff48.jsonl
# Successfully read 2214 events in a writing session from ./coauthor-v1.0/734cbb77f63544e5bce5a23f35c9f601.jsonl
# Successfully read 2848 events in a writing session from ./coauthor-v1.0/1cb5822da5794e2a8bb6346c4959a4e3.jsonl
# Successfully read 1893 events in a writing session from ./coauthor-v1.0/66b87321ccb646ffb7ed0d0bd7edfc70.jsonl
# Successfully read 2068 events in a writing session from ./coauthor-v1.0/a155fa8cfd624d278fb8f37cc32b0565.jsonl
# Successfully read 1570 events in a writing session from ./coauthor-v1.0/8485dc74018447939e7fd20e351b63c9.jsonl
# Successfully read 1992 events in a writing session from ./coauthor-v1.0/80e39947253d4491a8b294de724100f0.jsonl
# Successfully read 1276 events in a writing session from ./coauthor-v1.0/f4726c879c9d4e43ab6a63a3d732a988.jsonl
# Successfully read 2062 events in a writing session from ./coauthor-v1.0/876a292223a74b1a8ad5525d93b26d69.jsonl
# Successfully read 1524 events in a writing session from ./coauthor-v1.0/0b7c8c2c9e9141e3874e5782b3c41ea1.jsonl
# Successfully read 1915 events in a writing session from ./coauthor-v1.0/fbd1b7a3b81f4efc88b0605de907aea3.jsonl
# Successfully read 2030 events in a writing session from ./coauthor-v1.0/a2b882ca8a14420a8749dfedfecdfa36.jsonl
# Successfully read 2553 events in a writing session from ./coauthor-v1.0/836d8f49af1340ee84cd534b2051bd34.jsonl
# Successfully read 1931 events in a writing session from ./coauthor-v1.0/549faa4663e44ffbb3f26beca1bf95bb.jsonl
# Successfully read 1164 events in a writing session from ./coauthor-v1.0/1d62258005fb48a481225aed62066b36.jsonl
# Successfully read 1150 events in a writing session from ./coauthor-v1.0/233f1efcf0274acba92f46bf2f8766d2.jsonl
# Successfully read 1658 events in a writing session from ./coauthor-v1.0/278c77bedc924472bf0f0061598575ca.jsonl
# Successfully read 3098 events in a writing session from ./coauthor-v1.0/3461ee41df7f4f5fa584f5ae04b3ba6f.jsonl
# Successfully read 1431 events in a writing session from ./coauthor-v1.0/f3bd97b3642443f0869190c50ad0b771.jsonl
# Successfully read 1671 events in a writing session from ./coauthor-v1.0/2d9bcb435a994711829fe6b05f256fdb.jsonl
# Successfully read 1060 events in a writing session from ./coauthor-v1.0/90c79f94b57b4ef2b3c7d9c4598b7afa.jsonl
# Successfully read 2817 events in a writing session from ./coauthor-v1.0/ab54a76d5f3643ca95b0a24783f26921.jsonl
# Successfully read 1954 events in a writing session from ./coauthor-v1.0/3b6bdac8643a446989473560476d77a5.jsonl
# Successfully read 2078 events in a writing session from ./coauthor-v1.0/4eeea91c57b0425b9faf9bc4b74ec2be.jsonl
# Successfully read 1363 events in a writing session from ./coauthor-v1.0/64ded59bfd264094a10a88c47e4ecc1c.jsonl
# Successfully read 1530 events in a writing session from ./coauthor-v1.0/b3a1b8cfb7d94eb3a615600d440a0bc1.jsonl
# Successfully read 884 events in a writing session from ./coauthor-v1.0/be3ca3b27136433fb002393bc6f4689d.jsonl
# Successfully read 2511 events in a writing session from ./coauthor-v1.0/4be21e1efc0b433bb4c32954340f3da6.jsonl
# Successfully read 1050 events in a writing session from ./coauthor-v1.0/4e45f719739a423899b044f67aee9eb0.jsonl
# Successfully read 2110 events in a writing session from ./coauthor-v1.0/57514b6dd0764421a04c0b7a640c926b.jsonl
# Successfully read 1950 events in a writing session from ./coauthor-v1.0/b27f544a5f6e4989aa95af488cfeaadb.jsonl
# Successfully read 866 events in a writing session from ./coauthor-v1.0/bd374899c3cb4c83bf9b206791fbd70f.jsonl
# Successfully read 2785 events in a writing session from ./coauthor-v1.0/8590b229160046b698adbd688baf377f.jsonl
# Successfully read 2374 events in a writing session from ./coauthor-v1.0/242eb23d0a2a46a789be2b41a665873d.jsonl
# Successfully read 1682 events in a writing session from ./coauthor-v1.0/94517582b37d4ce6b9aeb4a0f9b7eed6.jsonl
# Successfully read 1440 events in a writing session from ./coauthor-v1.0/ccd58d9e5614445c9ee036243195b7cf.jsonl
# Successfully read 716 events in a writing session from ./coauthor-v1.0/67edbcbb485547d18993a50ef6dc5c92.jsonl
# Successfully read 2293 events in a writing session from ./coauthor-v1.0/1745a412b5cb4638b35b9f6f63eb3e0b.jsonl
# Successfully read 2144 events in a writing session from ./coauthor-v1.0/b72437b88da64ad392d21dbc32ca9af0.jsonl
# Successfully read 3571 events in a writing session from ./coauthor-v1.0/af58ab552c724ef2bff4dd8108581e1c.jsonl
# Successfully read 1608 events in a writing session from ./coauthor-v1.0/34919f6ff8774bca9c7632e79f43b572.jsonl
# Successfully read 566 events in a writing session from ./coauthor-v1.0/08182f9617eb4a5ea65ace997be70b9b.jsonl
# Successfully read 2541 events in a writing session from ./coauthor-v1.0/ea22b448ed0441a093211cc71c8c35e3.jsonl
# Successfully read 1159 events in a writing session from ./coauthor-v1.0/3d3b51040a84446a8576ff28a1c9887a.jsonl
# Successfully read 1406 events in a writing session from ./coauthor-v1.0/3fdafca346c94f52ac5b9588a48e0a56.jsonl
# Successfully read 1312 events in a writing session from ./coauthor-v1.0/ccbcf12b87b04596848a5091118c49d9.jsonl
# Successfully read 3708 events in a writing session from ./coauthor-v1.0/2043279d646845e9b3875b5d0a66d610.jsonl
# Successfully read 1282 events in a writing session from ./coauthor-v1.0/a068c6552ba143c8ba4f378e49c3b640.jsonl
# Successfully read 1925 events in a writing session from ./coauthor-v1.0/7e400fae43e543b0a6719cc2974029de.jsonl
# Successfully read 1211 events in a writing session from ./coauthor-v1.0/d40c6dfd679b4152b3f9334e56053ecf.jsonl
# Successfully read 1527 events in a writing session from ./coauthor-v1.0/3d7f50f368ad4acdb051a9a31c886c9e.jsonl
# Successfully read 2307 events in a writing session from ./coauthor-v1.0/8fd8bba68ff245d9a7b61561da572c22.jsonl
# Successfully read 2343 events in a writing session from ./coauthor-v1.0/f86105405d7d4c87bbfcd6b91d5d53a3.jsonl
# Successfully read 1469 events in a writing session from ./coauthor-v1.0/789f87d67d884e1898dc4a6e2e0e9d7b.jsonl
# Successfully read 1597 events in a writing session from ./coauthor-v1.0/d7de4777f84246b8896f38fac0494b17.jsonl
# Successfully read 2639 events in a writing session from ./coauthor-v1.0/94e6de534f4b4e2d965348fc3f4e317d.jsonl
# Successfully read 922 events in a writing session from ./coauthor-v1.0/d85ddd25fd5641a78bc996b77c55e82a.jsonl
# Successfully read 841 events in a writing session from ./coauthor-v1.0/b4fdc128ddcb442b82eb4c0bc2607479.jsonl
# Successfully read 1711 events in a writing session from ./coauthor-v1.0/b6683afb932a48dbaa3ba337f1ee1db1.jsonl
# Successfully read 2081 events in a writing session from ./coauthor-v1.0/e4bf8d4c04c743b39fb94f724339f642.jsonl
# Successfully read 2343 events in a writing session from ./coauthor-v1.0/f670362dc84144aabb373a577490e491.jsonl
# Successfully read 1491 events in a writing session from ./coauthor-v1.0/1ece5cdde9bc44439c5f117d31e73dbf.jsonl
# Successfully read 2855 events in a writing session from ./coauthor-v1.0/85e6bf7f0f3844f3a9f88b7f3350e6f6.jsonl
# Successfully read 2983 events in a writing session from ./coauthor-v1.0/5e7e514646ae4e468f3f20972dac1ddc.jsonl
# Successfully read 1408 events in a writing session from ./coauthor-v1.0/913991c2f1c843f68d2f549533418965.jsonl
# Successfully read 1984 events in a writing session from ./coauthor-v1.0/10638735a10248c29ef1747f2f12c0b7.jsonl
# Successfully read 1804 events in a writing session from ./coauthor-v1.0/eb052c37796c4ae3b8b5c77c800684c6.jsonl
# Successfully read 2932 events in a writing session from ./coauthor-v1.0/ead266bd00fd4423be98ad8176af3a17.jsonl
# Successfully read 2439 events in a writing session from ./coauthor-v1.0/51811494ceb647a8aa633d4c7c3e089f.jsonl
# Successfully read 3376 events in a writing session from ./coauthor-v1.0/a7b9f3e4d2c547c3a739567a81c0de08.jsonl
# Successfully read 926 events in a writing session from ./coauthor-v1.0/e1fd275c34ab4aae9e3a119b0dd3f0b4.jsonl
# Successfully read 1531 events in a writing session from ./coauthor-v1.0/c790716311e749bfac75cde237a3f5b6.jsonl
# Successfully read 1540 events in a writing session from ./coauthor-v1.0/ff21eabc9606411ba8cd583fdcdfe72c.jsonl
# Successfully read 1589 events in a writing session from ./coauthor-v1.0/c5af75674d5b4710a0bb470ff3761ad7.jsonl
# Successfully read 2598 events in a writing session from ./coauthor-v1.0/6e21e7baba4d414ebc3218a051cce679.jsonl
# Successfully read 2575 events in a writing session from ./coauthor-v1.0/269f101ba0da4aa3a5ce0bf3a65bade1.jsonl
# Successfully read 667 events in a writing session from ./coauthor-v1.0/c6c9790c4a044b94b6412a7abd98c8c5.jsonl
# Successfully read 2483 events in a writing session from ./coauthor-v1.0/240b61c1abc24288a19f6faa9909e719.jsonl
# Successfully read 1455 events in a writing session from ./coauthor-v1.0/1049b04745b44e7fa2a50d98321c2026.jsonl
# Successfully read 1364 events in a writing session from ./coauthor-v1.0/309c885c1f7e483681d807a14b36c831.jsonl
# Successfully read 3379 events in a writing session from ./coauthor-v1.0/3d6d562a736a49509c20be372a83d111.jsonl
# Successfully read 1628 events in a writing session from ./coauthor-v1.0/0701c34e77564a46accbddb80138116c.jsonl
# Successfully read 2041 events in a writing session from ./coauthor-v1.0/82eec1c4618e494c88253f4e5167fc26.jsonl
# Successfully read 3074 events in a writing session from ./coauthor-v1.0/c291ea51ad6c42a887c1fd2464edebe1.jsonl
# Successfully read 1316 events in a writing session from ./coauthor-v1.0/3ca31115e49946af820f4e5c6cc31311.jsonl
# Successfully read 1227 events in a writing session from ./coauthor-v1.0/9e408240b6c34495b3d20597eaa1dd80.jsonl
# Successfully read 2668 events in a writing session from ./coauthor-v1.0/04ebdfae0edc4adcb7e59ff060b45e72.jsonl
# Successfully read 1973 events in a writing session from ./coauthor-v1.0/b7687cecbf6c4c18a04b5b0b9b031cf4.jsonl
# Successfully read 2711 events in a writing session from ./coauthor-v1.0/b2340ae8050543cbb74906ff4a96e850.jsonl
# Successfully read 2102 events in a writing session from ./coauthor-v1.0/5f43b93d95334de7a886100e5e0a73b8.jsonl
# Successfully read 1380 events in a writing session from ./coauthor-v1.0/b6e3af6257c84970bf770a3b30c573c7.jsonl
# Successfully read 1507 events in a writing session from ./coauthor-v1.0/4ef600b3d75344abaad59aadc0fe200a.jsonl
# Successfully read 2006 events in a writing session from ./coauthor-v1.0/75502f7ab83b42189c79a1972db22bb0.jsonl
# Successfully read 1396 events in a writing session from ./coauthor-v1.0/c42ae1a2e39e4d63ab7beaf4139150d0.jsonl
# Successfully read 2117 events in a writing session from ./coauthor-v1.0/ff0d41e1426c410bbf87423713ac5e89.jsonl
# Successfully read 1372 events in a writing session from ./coauthor-v1.0/1ab526811cb04829be91e2ac7fd18b67.jsonl
# Successfully read 2483 events in a writing session from ./coauthor-v1.0/86d3e1410ca24ecfa486a6b3059b2618.jsonl
# Successfully read 1426 events in a writing session from ./coauthor-v1.0/fdd85d76a9eb42d994e75ce952202309.jsonl
# Successfully read 1460 events in a writing session from ./coauthor-v1.0/f1c5ca52c9754a37b10dce55cf5113e2.jsonl
# Successfully read 2102 events in a writing session from ./coauthor-v1.0/0554d7947d9444bc96f9a9512f4ae989.jsonl
# Successfully read 2652 events in a writing session from ./coauthor-v1.0/4b119edd75174d1fa4a4c3c63493ae11.jsonl
# Successfully read 2863 events in a writing session from ./coauthor-v1.0/c9e301f54a8a4723b14567a99c90d2b7.jsonl
# Successfully read 1177 events in a writing session from ./coauthor-v1.0/797e87aff94142b1be301e11df758d63.jsonl
# Successfully read 2196 events in a writing session from ./coauthor-v1.0/0a08f7fd748246c8ad4e353edb7e2394.jsonl
# Successfully read 1211 events in a writing session from ./coauthor-v1.0/745644f53bdc47409855cc751518e25b.jsonl
# Successfully read 1959 events in a writing session from ./coauthor-v1.0/bbf66945de704afe9c3054b659f7c6d8.jsonl
# Successfully read 1472 events in a writing session from ./coauthor-v1.0/9c8cd9880da74366ba28673147d87d34.jsonl
# Successfully read 1992 events in a writing session from ./coauthor-v1.0/ed0280fb0f114ead8a22516a8309f982.jsonl
# Successfully read 1158 events in a writing session from ./coauthor-v1.0/4e3e3c07acd645eeac9f8a18dcc9b796.jsonl
# Successfully read 3027 events in a writing session from ./coauthor-v1.0/c4e852c4b21b4703a485d93b618361cd.jsonl
# Successfully read 1378 events in a writing session from ./coauthor-v1.0/18d61fce4bcc4ccf9bd49c621b0ec1c0.jsonl
# Successfully read 2214 events in a writing session from ./coauthor-v1.0/84d37eaac05e42fd84fda709a661cf51.jsonl
# Successfully read 1328 events in a writing session from ./coauthor-v1.0/3657ba7cb1a14cc6835c24d68176c42b.jsonl
# Successfully read 1852 events in a writing session from ./coauthor-v1.0/7b2aaf58f55a434f91bb71515a329f13.jsonl
# Successfully read 1358 events in a writing session from ./coauthor-v1.0/e94df2820e7644688623158f859d77ec.jsonl
# Successfully read 1968 events in a writing session from ./coauthor-v1.0/6938b4a468aa482ba459d2fbe140cb30.jsonl
# Successfully read 1353 events in a writing session from ./coauthor-v1.0/1bb5ec50edd24bd8a1c6a6aad602b613.jsonl
# Successfully read 2316 events in a writing session from ./coauthor-v1.0/ad3a61d515cf456cbaa424c7b4ac0f13.jsonl
# Successfully read 2266 events in a writing session from ./coauthor-v1.0/41f6cb6f7e134246943e077e0d937970.jsonl
# Successfully read 2450 events in a writing session from ./coauthor-v1.0/3ab1ca63246449669bf1f7b9c90d379b.jsonl
# Successfully read 2947 events in a writing session from ./coauthor-v1.0/eec20f24484d418eb4ba564fbfbc2ab6.jsonl
# Successfully read 1089 events in a writing session from ./coauthor-v1.0/1e6ecfa3fa7c4fd7ad7c10470546f654.jsonl
# Successfully read 1970 events in a writing session from ./coauthor-v1.0/cac1461058604a49824731779448358d.jsonl
# Successfully read 2701 events in a writing session from ./coauthor-v1.0/b7bbabfaabda406ba45cd152872abf82.jsonl
# Successfully read 1014 events in a writing session from ./coauthor-v1.0/30786a82a19c45a6a77a12963fa21ea0.jsonl
# Successfully read 2121 events in a writing session from ./coauthor-v1.0/34d7c1032151410583aa9069286104d6.jsonl
# Successfully read 1959 events in a writing session from ./coauthor-v1.0/e6b54867c5fb4b8a9806a93b6cee4526.jsonl
# Successfully read 1627 events in a writing session from ./coauthor-v1.0/b6c08c13a3a24bfe81e6186207077368.jsonl
# Successfully read 1142 events in a writing session from ./coauthor-v1.0/e90a5ce2d98548a997fb8c3ab2213483.jsonl
# Successfully read 2260 events in a writing session from ./coauthor-v1.0/e416e61f2c7340c39290176e896de226.jsonl
# Successfully read 1238 events in a writing session from ./coauthor-v1.0/9614fb65fa5146549e303e13586a947b.jsonl
# Successfully read 2127 events in a writing session from ./coauthor-v1.0/0c7bfadbd8db49b4b793e2a46e581759.jsonl
# Successfully read 2011 events in a writing session from ./coauthor-v1.0/208569acde5b49dda0ec25ce4c410975.jsonl
# Successfully read 3119 events in a writing session from ./coauthor-v1.0/23b998c76c784ff29f0ddedd78128722.jsonl
# Successfully read 1460 events in a writing session from ./coauthor-v1.0/d1edc05d6a4a411db965bb9a8adc3339.jsonl
# Successfully read 1183 events in a writing session from ./coauthor-v1.0/d4759814eb5d4d17bfcbe373d0947e58.jsonl
# Successfully read 1371 events in a writing session from ./coauthor-v1.0/feb421930b1a46f2a4829239384c1bd9.jsonl
# Successfully read 993 events in a writing session from ./coauthor-v1.0/f31675baa0db4b3384abc09724eae09f.jsonl
# Successfully read 1550 events in a writing session from ./coauthor-v1.0/e3771827917b40df9c4b10981200336d.jsonl
# Successfully read 1828 events in a writing session from ./coauthor-v1.0/8a66ba50d4e241f2aebb17e5af82c68a.jsonl
# Successfully read 1750 events in a writing session from ./coauthor-v1.0/4cdeeb7605ca48f8a34eb3c688537ecd.jsonl
# Successfully read 1243 events in a writing session from ./coauthor-v1.0/406e98d0ec3c412397412ac18367d491.jsonl
# Successfully read 2162 events in a writing session from ./coauthor-v1.0/188aef2decc3415eaeba3467fe86116e.jsonl
# Successfully read 2263 events in a writing session from ./coauthor-v1.0/335ffea5a1a8426badc75a2fa056a1a8.jsonl
# Successfully read 1876 events in a writing session from ./coauthor-v1.0/5a17e70a18c04205aac7f7bb845b8333.jsonl
# Successfully read 2513 events in a writing session from ./coauthor-v1.0/9dc3070beb854b7db6c55d083cd41611.jsonl
# Successfully read 3696 events in a writing session from ./coauthor-v1.0/d08ae131480c41d8bfa5dc129fdd468c.jsonl
# Successfully read 1311 events in a writing session from ./coauthor-v1.0/c7dc5563ed07478f9284190b6085f4d3.jsonl
# Successfully read 3735 events in a writing session from ./coauthor-v1.0/35a38bcbc9e94604b0c731ca8cc5de51.jsonl
# Successfully read 1050 events in a writing session from ./coauthor-v1.0/9f2ba74210184ca1843adc31044612bb.jsonl
# Successfully read 747 events in a writing session from ./coauthor-v1.0/3b78cf42ca2b41cdbc067aeceaa82a92.jsonl
# Successfully read 1608 events in a writing session from ./coauthor-v1.0/b5cba1af4218432bac6932bd1d546125.jsonl
# Successfully read 1245 events in a writing session from ./coauthor-v1.0/b6c87b8153ce4791a449f6b80a7f438e.jsonl
# Successfully read 2845 events in a writing session from ./coauthor-v1.0/c5166a329a9c45f990a5d3c692d7faa0.jsonl
# Successfully read 2580 events in a writing session from ./coauthor-v1.0/223f27bcebb5496a850b7ce86d50e910.jsonl
# Successfully read 3114 events in a writing session from ./coauthor-v1.0/86a1a40bed5445c7bce7ac003f07d04c.jsonl
# Successfully read 2381 events in a writing session from ./coauthor-v1.0/826d810475364edcb986259d5f3cfac2.jsonl
# Successfully read 2076 events in a writing session from ./coauthor-v1.0/bb4c49c8ca6d4b818262cf983e1e2a84.jsonl
# Successfully read 1306 events in a writing session from ./coauthor-v1.0/25e8108b41f54a0ebfffb047cccf0f30.jsonl
# Successfully read 2800 events in a writing session from ./coauthor-v1.0/8b458eefa9304e608322239981e4ccd1.jsonl
# Successfully read 1372 events in a writing session from ./coauthor-v1.0/a37397d4adbe4733a8026d82dcf8d7a0.jsonl
# Successfully read 1840 events in a writing session from ./coauthor-v1.0/4398673bfcfd4ba388fb92f193fc582c.jsonl
# Successfully read 2242 events in a writing session from ./coauthor-v1.0/b185f407365540f2bc3e32d45bb3d154.jsonl
# Successfully read 1545 events in a writing session from ./coauthor-v1.0/95a0ce79d7ed4a77a0981c522b3deda7.jsonl
# Successfully read 1776 events in a writing session from ./coauthor-v1.0/40d132e1bc0146c0920d7b38c5b9f7c7.jsonl
# Successfully read 1734 events in a writing session from ./coauthor-v1.0/99038d19ea0740af917ecca9a303b06e.jsonl
# Successfully read 1914 events in a writing session from ./coauthor-v1.0/ddcc9eff5afa41889aa05c3025b604a6.jsonl
# Successfully read 2145 events in a writing session from ./coauthor-v1.0/8950ddb597804d51b4cc61f144e96338.jsonl
# Successfully read 1521 events in a writing session from ./coauthor-v1.0/626255ec39a349df84e75196a01c9e55.jsonl
# Successfully read 1123 events in a writing session from ./coauthor-v1.0/26091bf5237b4586b9417be5d4ce7484.jsonl
# Successfully read 1474 events in a writing session from ./coauthor-v1.0/fcd4884cb1ad44e0b1a1e1304cd61cb0.jsonl
# Successfully read 2381 events in a writing session from ./coauthor-v1.0/9c1de5d748a0486b8276ccce9f1c9f45.jsonl
# Successfully read 1897 events in a writing session from ./coauthor-v1.0/79757c30997549af8a2d741ed49ff453.jsonl
# Successfully read 2038 events in a writing session from ./coauthor-v1.0/eb15a76230f74cf781b0ace876dec6de.jsonl
# Successfully read 2234 events in a writing session from ./coauthor-v1.0/562f6952bc854fb3ace39e940b786320.jsonl
# Successfully read 1491 events in a writing session from ./coauthor-v1.0/477a7999cb944914ba1a1141db81b44f.jsonl
# Successfully read 1626 events in a writing session from ./coauthor-v1.0/f170aa855728465589f57f1c3154f55a.jsonl
# Successfully read 2929 events in a writing session from ./coauthor-v1.0/6363bd9d985e41f79f3bfb8e04fa3b5e.jsonl
# Successfully read 2100 events in a writing session from ./coauthor-v1.0/01a3e8d4e52f4f1483bf48b33cd88cd9.jsonl
# Successfully read 1498 events in a writing session from ./coauthor-v1.0/ebe81e9a3f3943e0bbfccca97f752e41.jsonl
# Successfully read 736 events in a writing session from ./coauthor-v1.0/87428217b0aa4ca8a6001d5c46333f90.jsonl
# Successfully read 1370 events in a writing session from ./coauthor-v1.0/4cb270632c6e47f5ba6d606d53f66cd0.jsonl
# Successfully read 4610 events in a writing session from ./coauthor-v1.0/aa092c2e66ea48d89361cc668d7d4919.jsonl
# Successfully read 1384 events in a writing session from ./coauthor-v1.0/4ba0ab41e7a6458eacf213c24050ade3.jsonl
# Successfully read 1021 events in a writing session from ./coauthor-v1.0/36bc101319da4b3590b96bce76f7c02c.jsonl
# Successfully read 1887 events in a writing session from ./coauthor-v1.0/fd520baa3a5a4cd3967318729d67382f.jsonl
# Successfully read 1268 events in a writing session from ./coauthor-v1.0/4951e256dc4f4b44a90c95f8af2f34b7.jsonl
# Successfully read 1528 events in a writing session from ./coauthor-v1.0/e1aca0ed8d134ee09510f62c2646be1c.jsonl
# Successfully read 3103 events in a writing session from ./coauthor-v1.0/9161cb7544bf4fca8c796ee3c5b6b150.jsonl
# Successfully read 940 events in a writing session from ./coauthor-v1.0/017c174e78ca46248ae1f6b43d5500d8.jsonl
# Successfully read 1502 events in a writing session from ./coauthor-v1.0/4efb9d8419ee42a3b2ec99f01f94e0a6.jsonl
# Successfully read 1028 events in a writing session from ./coauthor-v1.0/68e4049ae7b64e988703b135729ee29e.jsonl
# Successfully read 3021 events in a writing session from ./coauthor-v1.0/06239d83b27840aaa169512cc8babda0.jsonl
# Successfully read 1333 events in a writing session from ./coauthor-v1.0/a1f6b84f1d60425ea7f1f34c2ff519e2.jsonl
# Successfully read 3179 events in a writing session from ./coauthor-v1.0/41950f3dbe8c4717b71d57f54c6ae0b7.jsonl
# Successfully read 2966 events in a writing session from ./coauthor-v1.0/64e545e776c1466687f0fe0dc8bb0d88.jsonl
# Successfully read 2343 events in a writing session from ./coauthor-v1.0/53d34e075dc2454ebbc4e4e8878b0d15.jsonl
# Successfully read 1586 events in a writing session from ./coauthor-v1.0/3d0be5ccb3ba4bf7aa4f243e70dcafd3.jsonl
# Successfully read 1304 events in a writing session from ./coauthor-v1.0/59db19c61039473a9da6c6e1f66b6c4e.jsonl
# Successfully read 2060 events in a writing session from ./coauthor-v1.0/60ac23b47a594ad881b0ee62839b1fcb.jsonl
# Successfully read 2593 events in a writing session from ./coauthor-v1.0/c7d83184f9f34ae9a9d55b0ee9176856.jsonl
# Successfully read 1949 events in a writing session from ./coauthor-v1.0/da3414296aae462498909b5fa7086161.jsonl
# ...
# Successfully read 2144 events in a writing session from ./coauthor-v1.0/dd87568fb11649f283279a507a1c2f11.jsonl
# Successfully read 1837 events in a writing session from ./coauthor-v1.0/8f3a8ff6a84e43c9a8e76a8de3936853.jsonl
# Successfully read 1563 events in a writing session from ./coauthor-v1.0/244d645564d1493f993123ac70f899e4.jsonl
# Successfully read 1536 events in a writing session from ./coauthor-v1.0/f8bc132e150846b18cfe36d6b9ad5ca5.jsonl
# Successfully read 1259 events in a writing session from ./coauthor-v1.0/864b77f0d5f34f2b9946e518cdeee98a.jsonl
# Successfully read 1751 events in a writing session from ./coauthor-v1.0/dcf41dcfdb0e4a98949063447b455792.jsonl
# Successfully read 1764 events in a writing session from ./coauthor-v1.0/f1523aa1deaa487c917db18be99ac355.jsonl
# Successfully read 3792 events in a writing session from ./coauthor-v1.0/b6acb37208be4f3e96965f989fd6f9fb.jsonl
# Successfully read 2001 events in a writing session from ./coauthor-v1.0/712c00cd50254b2baef9a6af57cfad72.jsonl
# Successfully read 2204 events in a writing session from ./coauthor-v1.0/c65f1ff1c8674f12bbb3a4a4b62ec7f1.jsonl
# Successfully read 1760 events in a writing session from ./coauthor-v1.0/676557098dfe452d88e87d3a01b5100b.jsonl
# Successfully read 918 events in a writing session from ./coauthor-v1.0/fe7442150cf74ed99d61e116a8a5426b.jsonl
# Successfully read 1951 events in a writing session from ./coauthor-v1.0/1c6fcfe3faf4499bad4a08f36fb0e941.jsonl
# Successfully read 1068 events in a writing session from ./coauthor-v1.0/21c3924c87fe4c8397bd84b3dce54dc5.jsonl
# Successfully read 2782 events in a writing session from ./coauthor-v1.0/25ad6925dd65422989e3659250ac9bfd.jsonl
# Successfully read 1484 events in a writing session from ./coauthor-v1.0/1d9be0e721ca4537a2cd16c0a0fd7630.jsonl
# Successfully read 2603 events in a writing session from ./coauthor-v1.0/ad936817fa674c3fb2db5f6d55fc49f1.jsonl
# Successfully read 1296 events in a writing session from ./coauthor-v1.0/ed645ae457f04bdda9562f4aa0003ce1.jsonl
# Successfully read 1761 events in a writing session from ./coauthor-v1.0/77f7082a5846485e95262a6dc0ffed79.jsonl
# Successfully read 1657 events in a writing session from ./coauthor-v1.0/ba74a6b6e52d42318d8ab8ab67651632.jsonl
# Successfully read 1596 events in a writing session from ./coauthor-v1.0/85a0e0a84eb147eeb0f2db0b946bab2e.jsonl
# Successfully read 2362 events in a writing session from ./coauthor-v1.0/95804c7277db4d538b06492830bed43c.jsonl
# Successfully read 1473 events in a writing session from ./coauthor-v1.0/9263032ff341476289f96ee1651ddd5a.jsonl
# Successfully read 3715 events in a writing session from ./coauthor-v1.0/9acd2cb9d930425fba58dfd597a8449a.jsonl
# Successfully read 3220 events in a writing session from ./coauthor-v1.0/78584b68efc441dc9e63092f93760523.jsonl
# Successfully read 1742 events in a writing session from ./coauthor-v1.0/761aaf53b31f4cfda836ca0802f22278.jsonl
# Successfully read 2445 events in a writing session from ./coauthor-v1.0/65002bc1af0b4d27a1b05e85d0090955.jsonl
# Successfully read 1085 events in a writing session from ./coauthor-v1.0/5a9ce5e82d814d418a7a1a0be11d36ac.jsonl
# Successfully read 806 events in a writing session from ./coauthor-v1.0/34cb11d1be2f4a60a350d9d5e6dc45f6.jsonl
# Successfully read 1643 events in a writing session from ./coauthor-v1.0/fe0fb4892ea749c7a67b12172793c3a4.jsonl
# Successfully read 2573 events in a writing session from ./coauthor-v1.0/105bf88bb4bc42688e06a54644e2989b.jsonl
# Successfully read 1473 events in a writing session from ./coauthor-v1.0/b48593a56908434488ca3c140744c642.jsonl
# Successfully read 1811 events in a writing session from ./coauthor-v1.0/825d93ee72ec4f8390286a45eca1a2a6.jsonl
# Successfully read 3488 events in a writing session from ./coauthor-v1.0/9a29f841869a4fd98cf358da50f4a340.jsonl
# Successfully read 977 events in a writing session from ./coauthor-v1.0/d4b47a8a66b84e8ebdf986e6d4edf139.jsonl
# Successfully read 687 events in a writing session from ./coauthor-v1.0/6395e22e141c4ee0bf233b95a63a61ea.jsonl
# Successfully read 1420 events in a writing session from ./coauthor-v1.0/3fd4689bc9384b6180595d77d771a312.jsonl
# Successfully read 2671 events in a writing session from ./coauthor-v1.0/a4e360c64c944328afc066c7a321575f.jsonl
# Successfully read 1442 events in a writing session from ./coauthor-v1.0/f84d42f7c64c4b92b75b3d718a99c8c4.jsonl
# Successfully read 2379 events in a writing session from ./coauthor-v1.0/d85105525355435da52d20ce7a4b7620.jsonl
# Successfully read 1399 events in a writing session from ./coauthor-v1.0/b75ef56faed74be0b4b59e15138e18f4.jsonl
# Successfully read 1726 events in a writing session from ./coauthor-v1.0/ceaefdd012e2487990dd4fc021233919.jsonl
# Successfully read 1675 events in a writing session from ./coauthor-v1.0/5926ac21bce54d03a6acc6054c6bdbf5.jsonl
# Successfully read 874 events in a writing session from ./coauthor-v1.0/2f923aba101d46dc9bfca5a6664342d7.jsonl
# Successfully read 1942 events in a writing session from ./coauthor-v1.0/8cce12dd32d841368470d67ab55f4efb.jsonl
# Successfully read 2022 events in a writing session from ./coauthor-v1.0/c286d6136e35488f967ec0581cc49cfd.jsonl
# Successfully read 1241 events in a writing session from ./coauthor-v1.0/aa563d648ec34088a3e6d3924b53cffe.jsonl
# Successfully read 2828 events in a writing session from ./coauthor-v1.0/d714bc54e0dc4819bafa77a93927817b.jsonl
# Successfully read 1717 events in a writing session from ./coauthor-v1.0/b1764d1ab84a4d23a983a53fff269aed.jsonl
# Successfully read 1603 events in a writing session from ./coauthor-v1.0/ab72069c90cb4448a2c6fcaec1df7787.jsonl
# Successfully read 6622 events in a writing session from ./coauthor-v1.0/93cd61b41e0f46dd8af1468977c91ef7.jsonl
# Successfully read 1785 events in a writing session from ./coauthor-v1.0/c6fe39f226d74fa59bd666ff93329993.jsonl
# Successfully read 1405 events in a writing session from ./coauthor-v1.0/e6011509fc00436ab743f12fa6a27714.jsonl
# Successfully read 2155 events in a writing session from ./coauthor-v1.0/47f742905ea748d3b71bcd2c5684a654.jsonl
# Successfully read 2699 events in a writing session from ./coauthor-v1.0/40de050696b84fc0b0150eb8ac1d86b4.jsonl
# Successfully read 2113 events in a writing session from ./coauthor-v1.0/2cd0471292f14be5bf1ccb9b313e1903.jsonl
# Successfully read 1361 events in a writing session from ./coauthor-v1.0/85ee6ffba76749fb8e6f066683b0a56a.jsonl
# Successfully read 3155 events in a writing session from ./coauthor-v1.0/6e1f579ba29946d1b88b76320de96dd0.jsonl
# Successfully read 2497 events in a writing session from ./coauthor-v1.0/8eb73d4db00044b1bb63808e3365e90c.jsonl
# Successfully read 563 events in a writing session from ./coauthor-v1.0/f8fd4fb1d3ae456a8a5dddefc9389aa3.jsonl
# Successfully read 1450 events in a writing session from ./coauthor-v1.0/092396c287e54c3d9454ba20bb1ccc83.jsonl
# Successfully read 2339 events in a writing session from ./coauthor-v1.0/49e04e987bbe4e59bf2baab73f486a26.jsonl
# Successfully read 2050 events in a writing session from ./coauthor-v1.0/2465c23b3c7e4d1dac1c5ee02bc878d7.jsonl
# Successfully read 1650 events in a writing session from ./coauthor-v1.0/61de020340f54d10a332f6aecc8079a5.jsonl
# Successfully read 1689 events in a writing session from ./coauthor-v1.0/c95024d4d29d4d90a8aa665aef6397aa.jsonl
# Successfully read 3023 events in a writing session from ./coauthor-v1.0/8f4fb63ec8e94e269f5a41f93e948bc5.jsonl
# Successfully read 2717 events in a writing session from ./coauthor-v1.0/9dc52675bffe43dd8a9359dab52e711b.jsonl
# Successfully read 2465 events in a writing session from ./coauthor-v1.0/07052b6123424ad2b3aadfb9910d0fc4.jsonl
# Successfully read 1740 events in a writing session from ./coauthor-v1.0/d92b90266d8444da9623553a6370cbb8.jsonl
# Successfully read 2338 events in a writing session from ./coauthor-v1.0/672cbc4dddf545218344122b24e3fd7a.jsonl
# Successfully read 1361 events in a writing session from ./coauthor-v1.0/7f9c5917c21f49ffb83d155fcc268ce9.jsonl
# Successfully read 2439 events in a writing session from ./coauthor-v1.0/b153deb333a648e8bed354ccb72d9085.jsonl
# Successfully read 3023 events in a writing session from ./coauthor-v1.0/6d202d48002c43bcaf2d3bd441a3a757.jsonl
# Successfully read 1586 events in a writing session from ./coauthor-v1.0/8e68479f14394dce8f30aaad91524538.jsonl
# Successfully read 1949 events in a writing session from ./coauthor-v1.0/65564e291348443491a3701f80d2b99d.jsonl
# Successfully read 1297 events in a writing session from ./coauthor-v1.0/2a08ae62ea9849cf8d3b48513dd1514d.jsonl
# Successfully read 3199 events in a writing session from ./coauthor-v1.0/5107cf5a8ad048e99b0d92892e98d40a.jsonl
# Successfully read 2397 events in a writing session from ./coauthor-v1.0/f0b4803428a846c6b22e2d420e980a33.jsonl
# Successfully read 1438 events in a writing session from ./coauthor-v1.0/cd99ed0ca6f244039d82b04f4e9fdc60.jsonl
# Successfully read 1401 events in a writing session from ./coauthor-v1.0/d4d4847e461c42888c2357e8d8f268b3.jsonl
# Successfully read 1848 events in a writing session from ./coauthor-v1.0/65db59a7705345ec88f5aafc812951ef.jsonl
# Successfully read 2783 events in a writing session from ./coauthor-v1.0/255895948b97428686b11c534cc8de9e.jsonl
# Successfully read 2071 events in a writing session from ./coauthor-v1.0/db169bdfdf294eaab67ca9aeb7a7f948.jsonl
# Successfully read 1864 events in a writing session from ./coauthor-v1.0/f13ca6a2519e4ddcaf454f11968ed676.jsonl
# Successfully read 1621 events in a writing session from ./coauthor-v1.0/d751bbe533c947da999264d16545705d.jsonl
# Successfully read 1700 events in a writing session from ./coauthor-v1.0/308df34d38ce447a957e540a6cde21c7.jsonl
# Successfully read 1812 events in a writing session from ./coauthor-v1.0/cc85690dead449a393defdea082229c8.jsonl
# Successfully read 1547 events in a writing session from ./coauthor-v1.0/0b755c9e2338496587d0b88471056e6b.jsonl
# Successfully read 1363 events in a writing session from ./coauthor-v1.0/5c524b4889834145ad435d84415f457c.jsonl
# Successfully read 3244 events in a writing session from ./coauthor-v1.0/83a18344884f45408957086dc933dfc7.jsonl
# Successfully read 750 events in a writing session from ./coauthor-v1.0/657931777f324506a86264da2d0d5793.jsonl
# Successfully read 2588 events in a writing session from ./coauthor-v1.0/c99f8c2465da42cc91498fd9d99e360b.jsonl
# Successfully read 1152 events in a writing session from ./coauthor-v1.0/f6aee07eece340eca425fbfe1d439a0c.jsonl
# Successfully read 1433 events in a writing session from ./coauthor-v1.0/56af97b16b6d444c8f8d55c740550837.jsonl
# Successfully read 2822 events in a writing session from ./coauthor-v1.0/575795c2253e49f9adb3bd64dd8bf896.jsonl
# Successfully read 1389 events in a writing session from ./coauthor-v1.0/474d81b6da2d453aa90eade3a94276a2.jsonl
# Successfully read 2038 events in a writing session from ./coauthor-v1.0/61f79cbacda542fd92422b4be43132b9.jsonl
# Successfully read 1264 events in a writing session from ./coauthor-v1.0/bd4dc28d6e1b469bb4b96239b8fcfef9.jsonl
# Successfully read 2598 events in a writing session from ./coauthor-v1.0/1f9525eb67504ccd8167402a950cdf1a.jsonl
# Successfully read 1663 events in a writing session from ./coauthor-v1.0/f84a83053e004acb9ccc912f7c6d8ec6.jsonl
# Successfully read 1791 events in a writing session from ./coauthor-v1.0/06bfae7a7e804288accd988a9d2259dd.jsonl
# Successfully read 1240 events in a writing session from ./coauthor-v1.0/0722c529c6924e989c5723366906e6d2.jsonl
# Successfully read 1824 events in a writing session from ./coauthor-v1.0/18de1e1d4baf4aabaf525a1f5bae3432.jsonl
# Successfully read 1380 events in a writing session from ./coauthor-v1.0/15a3a2aac98e48af9335bbdb3611892d.jsonl
# Successfully read 2165 events in a writing session from ./coauthor-v1.0/b153dcf4dae74acb8ebc70ff937ecccf.jsonl
# Successfully read 1194 events in a writing session from ./coauthor-v1.0/e29599231e66474b8a524c23db775e47.jsonl
# Successfully read 1168 events in a writing session from ./coauthor-v1.0/e257561129954362be03dc09727ad7a8.jsonl
# Successfully read 1225 events in a writing session from ./coauthor-v1.0/9b94bdf538854dee9dafd358ae40b55b.jsonl
# Successfully read 882 events in a writing session from ./coauthor-v1.0/536987ff6f5243f6b3f620aba1c3bbfa.jsonl
# Successfully read 2178 events in a writing session from ./coauthor-v1.0/9ec10cba9d8c48428d656fceff57e834.jsonl
# Successfully read 2823 events in a writing session from ./coauthor-v1.0/c6f8250e587f4288a48a616b2f1c1c6d.jsonl
# Successfully read 2047 events in a writing session from ./coauthor-v1.0/e473b59b1628452f9d7ac68bea6d36ff.jsonl
# Successfully read 1204 events in a writing session from ./coauthor-v1.0/229fee620c9e41f3bf737ffa9217b3d3.jsonl
# Successfully read 1033 events in a writing session from ./coauthor-v1.0/e2cdf3ffc1fb4396a67368c8331d4f58.jsonl
# Successfully read 2830 events in a writing session from ./coauthor-v1.0/2d9358657a364ccab47e9a7538cb6650.jsonl
# Successfully read 1466 events in a writing session from ./coauthor-v1.0/a3bb5d95c74a46fcbc44d24828f7ab0a.jsonl
# Successfully read 3272 events in a writing session from ./coauthor-v1.0/4542a8d2310247d1917ff1c79ac6171f.jsonl
# Successfully read 886 events in a writing session from ./coauthor-v1.0/17f65e14d6ab4f7596367a394daf3f82.jsonl
# Successfully read 1695 events in a writing session from ./coauthor-v1.0/f579d31e1bee4c75826e8a5f24a0f25f.jsonl
# Successfully read 1858 events in a writing session from ./coauthor-v1.0/5d3c9dbeb3e04c82ac88501a6668d530.jsonl
# Successfully read 869 events in a writing session from ./coauthor-v1.0/11142ca391e749809df56da90091adb4.jsonl
# Successfully read 1334 events in a writing session from ./coauthor-v1.0/4d44dbfbf4b34c8a9e28065b836b5893.jsonl
# Successfully read 1377 events in a writing session from ./coauthor-v1.0/931c030acd5e41b1bfac856da1aeb8e3.jsonl
# Successfully read 1449 events in a writing session from ./coauthor-v1.0/f019def862094e0fb2a5016674603d83.jsonl
# Successfully read 1337 events in a writing session from ./coauthor-v1.0/bd395e4c6ca24b7f802e1cf176ee908d.jsonl
# Successfully read 1969 events in a writing session from ./coauthor-v1.0/a7518c3553b7485a9e01e8bd95843abc.jsonl
# Successfully read 1653 events in a writing session from ./coauthor-v1.0/a754ad9eecca4d13954cf36eeda823b5.jsonl
# Successfully read 2494 events in a writing session from ./coauthor-v1.0/29e036276257406ea2b37fd5e71a56dc.jsonl
# Successfully read 2538 events in a writing session from ./coauthor-v1.0/ce969e3aa6374189abe638aa61b3ffc9.jsonl
# Successfully read 1442 events in a writing session from ./coauthor-v1.0/77f36111a79b43b086fe0306d8644e56.jsonl
# Successfully read 1241 events in a writing session from ./coauthor-v1.0/c96be18e04be41e48542d975337fbbed.jsonl
# Successfully read 1615 events in a writing session from ./coauthor-v1.0/0ff12af0651e4b0eaf88e22e82058137.jsonl
# Successfully read 1528 events in a writing session from ./coauthor-v1.0/47f1f3cedf5e4a779470a1816fd625dc.jsonl
# Successfully read 1870 events in a writing session from ./coauthor-v1.0/92532185a1a447e09fc3843b26c520db.jsonl
# Successfully read 1262 events in a writing session from ./coauthor-v1.0/ee760edb666e4f46aedee408975a9c9d.jsonl
# Successfully read 2923 events in a writing session from ./coauthor-v1.0/0f44162d5cef4e95bc4400529003a066.jsonl
# Successfully read 1733 events in a writing session from ./coauthor-v1.0/312e3263a9f24f3184364949a42a6dfc.jsonl
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[26], line 7
#       4 events = read_writing_session(path)
#       6 if len(events) < 3000:
# ----> 7     user_texts = reconstruct_user_text(events)
#       8     ai_suggestions = extract_selected_ai_suggestions(events)
#       9     acceptance_status = extract_acceptance_status(events)
#
# Cell In[5], line 19, in reconstruct_user_text(events)
#      17     for op in text_delta['ops']:
#      18         if 'insert' in op:
# ---> 19             extracted_text += op['insert']
#      20     current_text += extracted_text
#      22 elif event_type == "text-delete" and text_delta:
#
# TypeError: can only concatenate str (not "dict") to str

# %%
# Create dataframe
df_results = pd.DataFrame(jsd_results)
df_results.to_csv("all_metrics.csv", index=False)

# %%
import pandas as pd

# Load the existing "main" file
df_main = pd.read_csv("new.csv")

# Load the file that needs to be merged into the main file
df_other = pd.read_csv("merged.csv")

# Filter out rows in df_other where 'path' is already present in df_main
df_other_filtered = df_other[~df_other['path'].isin(df_main['path'])]

# Concatenate the new rows to the main dataframe
df_merged = pd.concat([df_main, df_other_filtered], ignore_index=True)

# Save the merged result to a new CSV (or overwrite the original if desired)
df_merged.to_csv("merged2.csv", index=False)
